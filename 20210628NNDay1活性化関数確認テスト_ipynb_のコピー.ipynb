# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahitoKatsuki/RabbitChallenge/blob/main/20210628NNDay1%E6%B4%BB%E6%80%A7%E5%8C%96%E9%96%A2%E6%95%B0%E7%A2%BA%E8%AA%8D%E3%83%86%E3%82%B9%E3%83%88_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#確認テスト1　線形性と非線形性の違い
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pillowをインポート
from PIL import Image

# 画像パス
filename = "/content/drive/MyDrive/DNN_code/NNDay1確認テスト活性化関数.jpg"

# Pillowで開く
im = Image.open(filename)

# 表示
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3000x4000 at 0x7F32A26EC9D0>

# %%
#確認テスト2 配布されたソースコードより、「順伝播（3層・複数ユニット）」から、活性化関数に該当する箇所を抜き出せ。
#入力層の出力および中間層の出力がReLUかかっている。
# 1層の総出力
z1 = functions.relu(u1)
    
# 2層の総出力
z2 = functions.relu(u2)

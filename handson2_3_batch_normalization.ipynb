# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahitoKatsuki/RabbitChallenge/blob/main/handson2_3_batch_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')
sys.path.append('/content/drive/My Drive/DNN_code/lesson_2')

# %% [markdown]
# # batch normalization

# %%
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer

# バッチ正則化 layer
class BatchNormalization:
    '''
    gamma: スケール係数
    beta: オフセット
    momentum: 慣性
    running_mean: テスト時に使用する平均
    running_var: テスト時に使用する分散
    '''
    def __init__(self, gamma, beta, momentum=0.9, running_mean=None, running_var=None):
        self.gamma = gamma
        self.beta = beta
        self.momentum = momentum
        self.input_shape = None

        self.running_mean = running_mean
        self.running_var = running_var  
        
        # backward時に使用する中間データ
        self.batch_size = None
        self.xc = None
        self.std = None
        self.dgamma = None
        self.dbeta = None

    def forward(self, x, train_flg=True):
        if self.running_mean is None:
            N, D = x.shape
            self.running_mean = np.zeros(D)
            self.running_var = np.zeros(D)
                        
        if train_flg:
            mu = x.mean(axis=0) # 平均
            xc = x - mu # xをセンタリング
            var = np.mean(xc**2, axis=0) # 分散
            std = np.sqrt(var + 10e-7) # スケーリング
            xn = xc / std
            
            self.batch_size = x.shape[0]
            self.xc = xc
            self.xn = xn
            self.std = std
            self.running_mean = self.momentum * self.running_mean + (1-self.momentum) * mu # 平均値の加重平均
            self.running_var = self.momentum * self.running_var + (1-self.momentum) * var #分散値の加重平均
        else:
            xc = x - self.running_mean
            xn = xc / ((np.sqrt(self.running_var + 10e-7)))
            
        out = self.gamma * xn + self.beta 
        
        return out

    def backward(self, dout):
        dbeta = dout.sum(axis=0)
        dgamma = np.sum(self.xn * dout, axis=0)
        dxn = self.gamma * dout
        dxc = dxn / self.std
        dstd = -np.sum((dxn * self.xc) / (self.std * self.std), axis=0)
        dvar = 0.5 * dstd / self.std
        dxc += (2.0 / self.batch_size) * self.xc * dvar
        dmu = np.sum(dxc, axis=0)
        dx = dxc - dmu / self.batch_size
        
        self.dgamma = dgamma
        self.dbeta = dbeta

        return dx

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.16
#                 : 10. 正答率(テスト) = 0.1421
# Generation: 20. 正答率(トレーニング) = 0.12
#                 : 20. 正答率(テスト) = 0.1666
# Generation: 30. 正答率(トレーニング) = 0.2
#                 : 30. 正答率(テスト) = 0.1868
# Generation: 40. 正答率(トレーニング) = 0.22
#                 : 40. 正答率(テスト) = 0.2133
# Generation: 50. 正答率(トレーニング) = 0.2
#                 : 50. 正答率(テスト) = 0.2368
# Generation: 60. 正答率(トレーニング) = 0.24
#                 : 60. 正答率(テスト) = 0.2666
# Generation: 70. 正答率(トレーニング) = 0.3
#                 : 70. 正答率(テスト) = 0.2948
# Generation: 80. 正答率(トレーニング) = 0.22
#                 : 80. 正答率(テスト) = 0.3352
# Generation: 90. 正答率(トレーニング) = 0.34
#                 : 90. 正答率(テスト) = 0.3887
# Generation: 100. 正答率(トレーニング) = 0.42
#                 : 100. 正答率(テスト) = 0.4379
# Generation: 110. 正答率(トレーニング) = 0.48
#                 : 110. 正答率(テスト) = 0.473
# Generation: 120. 正答率(トレーニング) = 0.5
#                 : 120. 正答率(テスト) = 0.4987
# Generation: 130. 正答率(トレーニング) = 0.51
#                 : 130. 正答率(テスト) = 0.5241
# Generation: 140. 正答率(トレーニング) = 0.55
#                 : 140. 正答率(テスト) = 0.5458
# Generation: 150. 正答率(トレーニング) = 0.53
#                 : 150. 正答率(テスト) = 0.5642
# Generation: 160. 正答率(トレーニング) = 0.71
#                 : 160. 正答率(テスト) = 0.5732
# Generation: 170. 正答率(トレーニング) = 0.61
#                 : 170. 正答率(テスト) = 0.5878
# Generation: 180. 正答率(トレーニング) = 0.57
#                 : 180. 正答率(テスト) = 0.5977
# Generation: 190. 正答率(トレーニング) = 0.54
#                 : 190. 正答率(テスト) = 0.6069
# Generation: 200. 正答率(トレーニング) = 0.58
#                 : 200. 正答率(テスト) = 0.6189
# Generation: 210. 正答率(トレーニング) = 0.62
#                 : 210. 正答率(テスト) = 0.6295
# Generation: 220. 正答率(トレーニング) = 0.67
#                 : 220. 正答率(テスト) = 0.6332
# Generation: 230. 正答率(トレーニング) = 0.61
#                 : 230. 正答率(テスト) = 0.6401
# Generation: 240. 正答率(トレーニング) = 0.62
#                 : 240. 正答率(テスト) = 0.6449
# Generation: 250. 正答率(トレーニング) = 0.62
#                 : 250. 正答率(テスト) = 0.655
# Generation: 260. 正答率(トレーニング) = 0.66
#                 : 260. 正答率(テスト) = 0.6644
# Generation: 270. 正答率(トレーニング) = 0.71
#                 : 270. 正答率(テスト) = 0.6697
# Generation: 280. 正答率(トレーニング) = 0.72
#                 : 280. 正答率(テスト) = 0.6746
# Generation: 290. 正答率(トレーニング) = 0.67
#                 : 290. 正答率(テスト) = 0.6775
# Generation: 300. 正答率(トレーニング) = 0.71
#                 : 300. 正答率(テスト) = 0.6836
# Generation: 310. 正答率(トレーニング) = 0.64
#                 : 310. 正答率(テスト) = 0.6842
# Generation: 320. 正答率(トレーニング) = 0.71
#                 : 320. 正答率(テスト) = 0.6951
# Generation: 330. 正答率(トレーニング) = 0.62
#                 : 330. 正答率(テスト) = 0.6996
# Generation: 340. 正答率(トレーニング) = 0.72
#                 : 340. 正答率(テスト) = 0.7074
# Generation: 350. 正答率(トレーニング) = 0.62
#                 : 350. 正答率(テスト) = 0.7105
# Generation: 360. 正答率(トレーニング) = 0.68
#                 : 360. 正答率(テスト) = 0.711
# Generation: 370. 正答率(トレーニング) = 0.72
#                 : 370. 正答率(テスト) = 0.7153
# Generation: 380. 正答率(トレーニング) = 0.65
#                 : 380. 正答率(テスト) = 0.7178
# Generation: 390. 正答率(トレーニング) = 0.73
#                 : 390. 正答率(テスト) = 0.7196
# Generation: 400. 正答率(トレーニング) = 0.73
#                 : 400. 正答率(テスト) = 0.7192
# Generation: 410. 正答率(トレーニング) = 0.72
#                 : 410. 正答率(テスト) = 0.7251
# Generation: 420. 正答率(トレーニング) = 0.77
#                 : 420. 正答率(テスト) = 0.728
# Generation: 430. 正答率(トレーニング) = 0.82
#                 : 430. 正答率(テスト) = 0.7309
# Generation: 440. 正答率(トレーニング) = 0.87
#                 : 440. 正答率(テスト) = 0.7341
# Generation: 450. 正答率(トレーニング) = 0.73
#                 : 450. 正答率(テスト) = 0.7364
# Generation: 460. 正答率(トレーニング) = 0.72
#                 : 460. 正答率(テスト) = 0.7364
# Generation: 470. 正答率(トレーニング) = 0.79
#                 : 470. 正答率(テスト) = 0.7393
# Generation: 480. 正答率(トレーニング) = 0.71
#                 : 480. 正答率(テスト) = 0.7413
# Generation: 490. 正答率(トレーニング) = 0.72
#                 : 490. 正答率(テスト) = 0.7414
# Generation: 500. 正答率(トレーニング) = 0.71
#                 : 500. 正答率(テスト) = 0.7414
# Generation: 510. 正答率(トレーニング) = 0.63
#                 : 510. 正答率(テスト) = 0.74
# Generation: 520. 正答率(トレーニング) = 0.72
#                 : 520. 正答率(テスト) = 0.7444
# Generation: 530. 正答率(トレーニング) = 0.78
#                 : 530. 正答率(テスト) = 0.7432
# Generation: 540. 正答率(トレーニング) = 0.71
#                 : 540. 正答率(テスト) = 0.747
# Generation: 550. 正答率(トレーニング) = 0.66
#                 : 550. 正答率(テスト) = 0.7508
# Generation: 560. 正答率(トレーニング) = 0.78
#                 : 560. 正答率(テスト) = 0.7546
# Generation: 570. 正答率(トレーニング) = 0.75
#                 : 570. 正答率(テスト) = 0.7527
# Generation: 580. 正答率(トレーニング) = 0.78
#                 : 580. 正答率(テスト) = 0.7545
# Generation: 590. 正答率(トレーニング) = 0.72
#                 : 590. 正答率(テスト) = 0.7549
# Generation: 600. 正答率(トレーニング) = 0.77
#                 : 600. 正答率(テスト) = 0.7554
# Generation: 610. 正答率(トレーニング) = 0.73
#                 : 610. 正答率(テスト) = 0.7567
# Generation: 620. 正答率(トレーニング) = 0.77
#                 : 620. 正答率(テスト) = 0.7624
# Generation: 630. 正答率(トレーニング) = 0.76
#                 : 630. 正答率(テスト) = 0.766
# Generation: 640. 正答率(トレーニング) = 0.82
#                 : 640. 正答率(テスト) = 0.7687
# Generation: 650. 正答率(トレーニング) = 0.68
#                 : 650. 正答率(テスト) = 0.7688
# Generation: 660. 正答率(トレーニング) = 0.88
#                 : 660. 正答率(テスト) = 0.7693
# Generation: 670. 正答率(トレーニング) = 0.76
#                 : 670. 正答率(テスト) = 0.7735
# Generation: 680. 正答率(トレーニング) = 0.78
#                 : 680. 正答率(テスト) = 0.7716
# Generation: 690. 正答率(トレーニング) = 0.76
#                 : 690. 正答率(テスト) = 0.7723
# Generation: 700. 正答率(トレーニング) = 0.86
#                 : 700. 正答率(テスト) = 0.772
# Generation: 710. 正答率(トレーニング) = 0.83
#                 : 710. 正答率(テスト) = 0.7794
# Generation: 720. 正答率(トレーニング) = 0.82
#                 : 720. 正答率(テスト) = 0.7795
# Generation: 730. 正答率(トレーニング) = 0.72
#                 : 730. 正答率(テスト) = 0.779
# Generation: 740. 正答率(トレーニング) = 0.7
#                 : 740. 正答率(テスト) = 0.7836
# Generation: 750. 正答率(トレーニング) = 0.77
#                 : 750. 正答率(テスト) = 0.781
# Generation: 760. 正答率(トレーニング) = 0.74
#                 : 760. 正答率(テスト) = 0.7815
# Generation: 770. 正答率(トレーニング) = 0.73
#                 : 770. 正答率(テスト) = 0.7813
# Generation: 780. 正答率(トレーニング) = 0.79
#                 : 780. 正答率(テスト) = 0.7804
# Generation: 790. 正答率(トレーニング) = 0.81
#                 : 790. 正答率(テスト) = 0.7827
# Generation: 800. 正答率(トレーニング) = 0.77
#                 : 800. 正答率(テスト) = 0.7866
# Generation: 810. 正答率(トレーニング) = 0.73
#                 : 810. 正答率(テスト) = 0.7837
# Generation: 820. 正答率(トレーニング) = 0.79
#                 : 820. 正答率(テスト) = 0.79
# Generation: 830. 正答率(トレーニング) = 0.77
#                 : 830. 正答率(テスト) = 0.7885
# Generation: 840. 正答率(トレーニング) = 0.77
#                 : 840. 正答率(テスト) = 0.7884
# Generation: 850. 正答率(トレーニング) = 0.83
#                 : 850. 正答率(テスト) = 0.7899
# Generation: 860. 正答率(トレーニング) = 0.75
#                 : 860. 正答率(テスト) = 0.7918
# Generation: 870. 正答率(トレーニング) = 0.78
#                 : 870. 正答率(テスト) = 0.7944
# Generation: 880. 正答率(トレーニング) = 0.79
#                 : 880. 正答率(テスト) = 0.7922
# Generation: 890. 正答率(トレーニング) = 0.83
#                 : 890. 正答率(テスト) = 0.7907
# Generation: 900. 正答率(トレーニング) = 0.83
#                 : 900. 正答率(テスト) = 0.7902
# Generation: 910. 正答率(トレーニング) = 0.73
#                 : 910. 正答率(テスト) = 0.7928
# Generation: 920. 正答率(トレーニング) = 0.85
#                 : 920. 正答率(テスト) = 0.7946
# Generation: 930. 正答率(トレーニング) = 0.83
#                 : 930. 正答率(テスト) = 0.7975
# Generation: 940. 正答率(トレーニング) = 0.77
#                 : 940. 正答率(テスト) = 0.7975
# Generation: 950. 正答率(トレーニング) = 0.76
#                 : 950. 正答率(テスト) = 0.7998
# Generation: 960. 正答率(トレーニング) = 0.76
#                 : 960. 正答率(テスト) = 0.8001
# Generation: 970. 正答率(トレーニング) = 0.81
#                 : 970. 正答率(テスト) = 0.8027
# Generation: 980. 正答率(トレーニング) = 0.78
#                 : 980. 正答率(テスト) = 0.8004
# Generation: 990. 正答率(トレーニング) = 0.8
#                 : 990. 正答率(テスト) = 0.8057
# Generation: 1000. 正答率(トレーニング) = 0.82
#                 : 1000. 正答率(テスト) = 0.8037

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 活性化関数や重みの初期値を変えてみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#中間層が５層にしてみた。その分計算コストがかかる。
#そのため、学習率を0.01から0.1にすると学習がより早く進行させる。
#同様の条件で初期値をランダムにしても（XavierやHeの初期値を使用しなくても）学習が進んだ。
#トータルとして計算も速く、精度も高くなった。

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
# use_batchnorm = True
use_batchnorm = True
# ====================================================

# network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
#                         activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)
# network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
#                         activation='relu', weight_init_std='He', use_batchnorm=use_batchnorm)
network = MultiLayerNet(input_size=784, hidden_size_list=[40, 40, 40, 40, 20], output_size=10, #5層にしている
                       activation='relu', weight_init_std=0.01, use_batchnorm=use_batchnorm) #バッチ正規化を行い、かつ初期値はHeやXavierを用いていない。


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate= 0.1 #0.01から0.1にすることでゆっくりではなく早めに学習させている。ただし、発散しないように注意必要。

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.35
#                 : 10. 正答率(テスト) = 0.3353
# Generation: 20. 正答率(トレーニング) = 0.58
#                 : 20. 正答率(テスト) = 0.5529
# Generation: 30. 正答率(トレーニング) = 0.59
#                 : 30. 正答率(テスト) = 0.602
# Generation: 40. 正答率(トレーニング) = 0.73
#                 : 40. 正答率(テスト) = 0.6451
# Generation: 50. 正答率(トレーニング) = 0.76
#                 : 50. 正答率(テスト) = 0.6527
# Generation: 60. 正答率(トレーニング) = 0.76
#                 : 60. 正答率(テスト) = 0.6662
# Generation: 70. 正答率(トレーニング) = 0.65
#                 : 70. 正答率(テスト) = 0.697
# Generation: 80. 正答率(トレーニング) = 0.63
#                 : 80. 正答率(テスト) = 0.7162
# Generation: 90. 正答率(トレーニング) = 0.69
#                 : 90. 正答率(テスト) = 0.6921
# Generation: 100. 正答率(トレーニング) = 0.76
#                 : 100. 正答率(テスト) = 0.678
# Generation: 110. 正答率(トレーニング) = 0.74
#                 : 110. 正答率(テスト) = 0.6987
# Generation: 120. 正答率(トレーニング) = 0.73
#                 : 120. 正答率(テスト) = 0.7085
# Generation: 130. 正答率(トレーニング) = 0.73
#                 : 130. 正答率(テスト) = 0.7196
# Generation: 140. 正答率(トレーニング) = 0.76
#                 : 140. 正答率(テスト) = 0.7234
# Generation: 150. 正答率(トレーニング) = 0.79
#                 : 150. 正答率(テスト) = 0.6927
# Generation: 160. 正答率(トレーニング) = 0.78
#                 : 160. 正答率(テスト) = 0.7263
# Generation: 170. 正答率(トレーニング) = 0.72
#                 : 170. 正答率(テスト) = 0.7198
# Generation: 180. 正答率(トレーニング) = 0.85
#                 : 180. 正答率(テスト) = 0.7566
# Generation: 190. 正答率(トレーニング) = 0.72
#                 : 190. 正答率(テスト) = 0.7427
# Generation: 200. 正答率(トレーニング) = 0.75
#                 : 200. 正答率(テスト) = 0.7083
# Generation: 210. 正答率(トレーニング) = 0.72
#                 : 210. 正答率(テスト) = 0.7139
# Generation: 220. 正答率(トレーニング) = 0.75
#                 : 220. 正答率(テスト) = 0.7073
# Generation: 230. 正答率(トレーニング) = 0.78
#                 : 230. 正答率(テスト) = 0.7315
# Generation: 240. 正答率(トレーニング) = 0.71
#                 : 240. 正答率(テスト) = 0.7169
# Generation: 250. 正答率(トレーニング) = 0.82
#                 : 250. 正答率(テスト) = 0.7524
# Generation: 260. 正答率(トレーニング) = 0.74
#                 : 260. 正答率(テスト) = 0.7245
# Generation: 270. 正答率(トレーニング) = 0.76
#                 : 270. 正答率(テスト) = 0.7128
# Generation: 280. 正答率(トレーニング) = 0.84
#                 : 280. 正答率(テスト) = 0.7581
# Generation: 290. 正答率(トレーニング) = 0.75
#                 : 290. 正答率(テスト) = 0.7305
# Generation: 300. 正答率(トレーニング) = 0.78
#                 : 300. 正答率(テスト) = 0.7348
# Generation: 310. 正答率(トレーニング) = 0.73
#                 : 310. 正答率(テスト) = 0.7391
# Generation: 320. 正答率(トレーニング) = 0.73
#                 : 320. 正答率(テスト) = 0.7569
# Generation: 330. 正答率(トレーニング) = 0.8
#                 : 330. 正答率(テスト) = 0.7264
# Generation: 340. 正答率(トレーニング) = 0.74
#                 : 340. 正答率(テスト) = 0.753
# Generation: 350. 正答率(トレーニング) = 0.78
#                 : 350. 正答率(テスト) = 0.7308
# Generation: 360. 正答率(トレーニング) = 0.8
#                 : 360. 正答率(テスト) = 0.7416
# Generation: 370. 正答率(トレーニング) = 0.84
#                 : 370. 正答率(テスト) = 0.731
# Generation: 380. 正答率(トレーニング) = 0.9
#                 : 380. 正答率(テスト) = 0.7824
# Generation: 390. 正答率(トレーニング) = 0.8
#                 : 390. 正答率(テスト) = 0.7872
# Generation: 400. 正答率(トレーニング) = 0.86
#                 : 400. 正答率(テスト) = 0.7833
# Generation: 410. 正答率(トレーニング) = 0.79
#                 : 410. 正答率(テスト) = 0.7839
# Generation: 420. 正答率(トレーニング) = 0.8
#                 : 420. 正答率(テスト) = 0.7916
# Generation: 430. 正答率(トレーニング) = 0.8
#                 : 430. 正答率(テスト) = 0.7526
# Generation: 440. 正答率(トレーニング) = 0.77
#                 : 440. 正答率(テスト) = 0.7763
# Generation: 450. 正答率(トレーニング) = 0.82
#                 : 450. 正答率(テスト) = 0.7713
# Generation: 460. 正答率(トレーニング) = 0.73
#                 : 460. 正答率(テスト) = 0.7557
# Generation: 470. 正答率(トレーニング) = 0.84
#                 : 470. 正答率(テスト) = 0.7561
# Generation: 480. 正答率(トレーニング) = 0.83
#                 : 480. 正答率(テスト) = 0.7754
# Generation: 490. 正答率(トレーニング) = 0.87
#                 : 490. 正答率(テスト) = 0.7925
# Generation: 500. 正答率(トレーニング) = 0.82
#                 : 500. 正答率(テスト) = 0.7578
# Generation: 510. 正答率(トレーニング) = 0.79
#                 : 510. 正答率(テスト) = 0.7596
# Generation: 520. 正答率(トレーニング) = 0.81
#                 : 520. 正答率(テスト) = 0.7951
# Generation: 530. 正答率(トレーニング) = 0.86
#                 : 530. 正答率(テスト) = 0.7627
# Generation: 540. 正答率(トレーニング) = 0.79
#                 : 540. 正答率(テスト) = 0.8025
# Generation: 550. 正答率(トレーニング) = 0.8
#                 : 550. 正答率(テスト) = 0.7666
# Generation: 560. 正答率(トレーニング) = 0.75
#                 : 560. 正答率(テスト) = 0.7429
# Generation: 570. 正答率(トレーニング) = 0.83
#                 : 570. 正答率(テスト) = 0.8052
# Generation: 580. 正答率(トレーニング) = 0.85
#                 : 580. 正答率(テスト) = 0.7878
# Generation: 590. 正答率(トレーニング) = 0.86
#                 : 590. 正答率(テスト) = 0.7731
# Generation: 600. 正答率(トレーニング) = 0.66
#                 : 600. 正答率(テスト) = 0.7614
# Generation: 610. 正答率(トレーニング) = 0.85
#                 : 610. 正答率(テスト) = 0.7929
# Generation: 620. 正答率(トレーニング) = 0.85
#                 : 620. 正答率(テスト) = 0.7968
# Generation: 630. 正答率(トレーニング) = 0.78
#                 : 630. 正答率(テスト) = 0.7792
# Generation: 640. 正答率(トレーニング) = 0.88
#                 : 640. 正答率(テスト) = 0.796
# Generation: 650. 正答率(トレーニング) = 0.76
#                 : 650. 正答率(テスト) = 0.7731
# Generation: 660. 正答率(トレーニング) = 0.8
#                 : 660. 正答率(テスト) = 0.8014
# Generation: 670. 正答率(トレーニング) = 0.78
#                 : 670. 正答率(テスト) = 0.7809
# Generation: 680. 正答率(トレーニング) = 0.81
#                 : 680. 正答率(テスト) = 0.8074
# Generation: 690. 正答率(トレーニング) = 0.86
#                 : 690. 正答率(テスト) = 0.8122
# Generation: 700. 正答率(トレーニング) = 0.84
#                 : 700. 正答率(テスト) = 0.7825
# Generation: 710. 正答率(トレーニング) = 0.85
#                 : 710. 正答率(テスト) = 0.7917
# Generation: 720. 正答率(トレーニング) = 0.82
#                 : 720. 正答率(テスト) = 0.8056
# Generation: 730. 正答率(トレーニング) = 0.74
#                 : 730. 正答率(テスト) = 0.7729
# Generation: 740. 正答率(トレーニング) = 0.81
#                 : 740. 正答率(テスト) = 0.7751
# Generation: 750. 正答率(トレーニング) = 0.84
#                 : 750. 正答率(テスト) = 0.8024
# Generation: 760. 正答率(トレーニング) = 0.79
#                 : 760. 正答率(テスト) = 0.8171
# Generation: 770. 正答率(トレーニング) = 0.8
#                 : 770. 正答率(テスト) = 0.8041
# Generation: 780. 正答率(トレーニング) = 0.91
#                 : 780. 正答率(テスト) = 0.7962
# Generation: 790. 正答率(トレーニング) = 0.78
#                 : 790. 正答率(テスト) = 0.7995
# Generation: 800. 正答率(トレーニング) = 0.89
#                 : 800. 正答率(テスト) = 0.8125
# Generation: 810. 正答率(トレーニング) = 0.83
#                 : 810. 正答率(テスト) = 0.7802
# Generation: 820. 正答率(トレーニング) = 0.83
#                 : 820. 正答率(テスト) = 0.8196
# Generation: 830. 正答率(トレーニング) = 0.76
#                 : 830. 正答率(テスト) = 0.7976
# Generation: 840. 正答率(トレーニング) = 0.79
#                 : 840. 正答率(テスト) = 0.7748
# Generation: 850. 正答率(トレーニング) = 0.78
#                 : 850. 正答率(テスト) = 0.7946
# Generation: 860. 正答率(トレーニング) = 0.86
#                 : 860. 正答率(テスト) = 0.8191
# Generation: 870. 正答率(トレーニング) = 0.78
#                 : 870. 正答率(テスト) = 0.7644
# Generation: 880. 正答率(トレーニング) = 0.8
#                 : 880. 正答率(テスト) = 0.8118
# Generation: 890. 正答率(トレーニング) = 0.76
#                 : 890. 正答率(テスト) = 0.7811
# Generation: 900. 正答率(トレーニング) = 0.77
#                 : 900. 正答率(テスト) = 0.7581
# Generation: 910. 正答率(トレーニング) = 0.9
#                 : 910. 正答率(テスト) = 0.8117
# Generation: 920. 正答率(トレーニング) = 0.82
#                 : 920. 正答率(テスト) = 0.7979
# Generation: 930. 正答率(トレーニング) = 0.83
#                 : 930. 正答率(テスト) = 0.7719
# Generation: 940. 正答率(トレーニング) = 0.82
#                 : 940. 正答率(テスト) = 0.8161
# Generation: 950. 正答率(トレーニング) = 0.8
#                 : 950. 正答率(テスト) = 0.8044
# Generation: 960. 正答率(トレーニング) = 0.81
#                 : 960. 正答率(テスト) = 0.8011
# Generation: 970. 正答率(トレーニング) = 0.8
#                 : 970. 正答率(テスト) = 0.8049
# Generation: 980. 正答率(トレーニング) = 0.85
#                 : 980. 正答率(テスト) = 0.7836
# Generation: 990. 正答率(トレーニング) = 0.83
#                 : 990. 正答率(テスト) = 0.79
# Generation: 1000. 正答率(トレーニング) = 0.74
#                 : 1000. 正答率(テスト) = 0.7707

# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahitoKatsuki/RabbitChallenge/blob/main/handson2_2_1_vanishing_gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')

# %% [markdown]
# # vanishing gradient

# %% [markdown]
# ## sigmoid - gauss

# %%
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)

    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    last_d_f = functions.d_softmax_with_loss
    
    
    # 出力層でのデルタ
    delta3 = last_d_f(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.03
#                 : 10. 正答率(テスト) = 0.0974
# Generation: 20. 正答率(トレーニング) = 0.08
#                 : 20. 正答率(テスト) = 0.1032
# Generation: 30. 正答率(トレーニング) = 0.09
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.1
#                 : 40. 正答率(テスト) = 0.101
# Generation: 50. 正答率(トレーニング) = 0.14
#                 : 50. 正答率(テスト) = 0.101
# Generation: 60. 正答率(トレーニング) = 0.05
#                 : 60. 正答率(テスト) = 0.101
# Generation: 70. 正答率(トレーニング) = 0.15
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.11
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.11
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.06
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.12
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.07
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.1
#                 : 130. 正答率(テスト) = 0.0974
# Generation: 140. 正答率(トレーニング) = 0.17
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.14
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.1
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.21
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.15
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.06
#                 : 190. 正答率(テスト) = 0.1028
# Generation: 200. 正答率(トレーニング) = 0.1
#                 : 200. 正答率(テスト) = 0.1028
# Generation: 210. 正答率(トレーニング) = 0.08
#                 : 210. 正答率(テスト) = 0.1028
# Generation: 220. 正答率(トレーニング) = 0.09
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.14
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.07
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.06
#                 : 250. 正答率(テスト) = 0.1028
# Generation: 260. 正答率(トレーニング) = 0.14
#                 : 260. 正答率(テスト) = 0.1028
# Generation: 270. 正答率(トレーニング) = 0.1
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.07
#                 : 280. 正答率(テスト) = 0.1028
# Generation: 290. 正答率(トレーニング) = 0.13
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.11
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.09
#                 : 310. 正答率(テスト) = 0.101
# Generation: 320. 正答率(トレーニング) = 0.09
#                 : 320. 正答率(テスト) = 0.1028
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1032
# Generation: 340. 正答率(トレーニング) = 0.1
#                 : 340. 正答率(テスト) = 0.1028
# Generation: 350. 正答率(トレーニング) = 0.11
#                 : 350. 正答率(テスト) = 0.1028
# Generation: 360. 正答率(トレーニング) = 0.13
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.08
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.08
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.05
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.15
#                 : 400. 正答率(テスト) = 0.1028
# Generation: 410. 正答率(トレーニング) = 0.2
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.14
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.1
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.15
#                 : 440. 正答率(テスト) = 0.0974
# Generation: 450. 正答率(トレーニング) = 0.09
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.08
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.07
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.11
#                 : 480. 正答率(テスト) = 0.0958
# Generation: 490. 正答率(トレーニング) = 0.09
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.1
#                 : 500. 正答率(テスト) = 0.101
# Generation: 510. 正答率(トレーニング) = 0.14
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.12
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.07
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.07
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.13
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.16
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.1
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.1
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.11
#                 : 600. 正答率(テスト) = 0.1009
# Generation: 610. 正答率(トレーニング) = 0.07
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.11
#                 : 620. 正答率(テスト) = 0.1032
# Generation: 630. 正答率(トレーニング) = 0.12
#                 : 630. 正答率(テスト) = 0.1032
# Generation: 640. 正答率(トレーニング) = 0.11
#                 : 640. 正答率(テスト) = 0.098
# Generation: 650. 正答率(トレーニング) = 0.1
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.1
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.12
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.12
#                 : 690. 正答率(テスト) = 0.1028
# Generation: 700. 正答率(トレーニング) = 0.09
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.11
#                 : 710. 正答率(テスト) = 0.1135
# Generation: 720. 正答率(トレーニング) = 0.15
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.16
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.16
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.14
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.07
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.07
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.12
#                 : 790. 正答率(テスト) = 0.101
# Generation: 800. 正答率(トレーニング) = 0.15
#                 : 800. 正答率(テスト) = 0.1009
# Generation: 810. 正答率(トレーニング) = 0.12
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.08
#                 : 820. 正答率(テスト) = 0.0974
# Generation: 830. 正答率(トレーニング) = 0.06
#                 : 830. 正答率(テスト) = 0.1028
# Generation: 840. 正答率(トレーニング) = 0.15
#                 : 840. 正答率(テスト) = 0.1028
# Generation: 850. 正答率(トレーニング) = 0.12
#                 : 850. 正答率(テスト) = 0.1028
# Generation: 860. 正答率(トレーニング) = 0.1
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.14
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.09
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.09
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.1
#                 : 900. 正答率(テスト) = 0.1028
# Generation: 910. 正答率(トレーニング) = 0.12
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.09
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.12
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.13
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.13
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.06
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.06
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.14
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.06
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.14
#                 : 1000. 正答率(テスト) = 0.1028
# Generation: 1010. 正答率(トレーニング) = 0.11
#                 : 1010. 正答率(テスト) = 0.1028
# Generation: 1020. 正答率(トレーニング) = 0.12
#                 : 1020. 正答率(テスト) = 0.1028
# Generation: 1030. 正答率(トレーニング) = 0.05
#                 : 1030. 正答率(テスト) = 0.1028
# Generation: 1040. 正答率(トレーニング) = 0.12
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.1
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.12
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.14
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.12
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.13
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.11
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.09
#                 : 1110. 正答率(テスト) = 0.1135
# Generation: 1120. 正答率(トレーニング) = 0.09
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.11
#                 : 1130. 正答率(テスト) = 0.1135
# Generation: 1140. 正答率(トレーニング) = 0.09
#                 : 1140. 正答率(テスト) = 0.1032
# Generation: 1150. 正答率(トレーニング) = 0.12
#                 : 1150. 正答率(テスト) = 0.1135
# Generation: 1160. 正答率(トレーニング) = 0.1
#                 : 1160. 正答率(テスト) = 0.1135
# Generation: 1170. 正答率(トレーニング) = 0.17
#                 : 1170. 正答率(テスト) = 0.1135
# Generation: 1180. 正答率(トレーニング) = 0.1
#                 : 1180. 正答率(テスト) = 0.1135
# Generation: 1190. 正答率(トレーニング) = 0.13
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.06
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.1
#                 : 1210. 正答率(テスト) = 0.1135
# Generation: 1220. 正答率(トレーニング) = 0.1
#                 : 1220. 正答率(テスト) = 0.1135
# Generation: 1230. 正答率(トレーニング) = 0.09
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.04
#                 : 1240. 正答率(テスト) = 0.1135
# Generation: 1250. 正答率(トレーニング) = 0.13
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.09
#                 : 1260. 正答率(テスト) = 0.1135
# Generation: 1270. 正答率(トレーニング) = 0.13
#                 : 1270. 正答率(テスト) = 0.1028
# Generation: 1280. 正答率(トレーニング) = 0.11
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.11
#                 : 1290. 正答率(テスト) = 0.1135
# Generation: 1300. 正答率(トレーニング) = 0.07
#                 : 1300. 正答率(テスト) = 0.1135
# Generation: 1310. 正答率(トレーニング) = 0.03
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.11
#                 : 1320. 正答率(テスト) = 0.1135
# Generation: 1330. 正答率(トレーニング) = 0.11
#                 : 1330. 正答率(テスト) = 0.1135
# Generation: 1340. 正答率(トレーニング) = 0.12
#                 : 1340. 正答率(テスト) = 0.1028
# Generation: 1350. 正答率(トレーニング) = 0.08
#                 : 1350. 正答率(テスト) = 0.1028
# Generation: 1360. 正答率(トレーニング) = 0.11
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.1
#                 : 1370. 正答率(テスト) = 0.0974
# Generation: 1380. 正答率(トレーニング) = 0.12
#                 : 1380. 正答率(テスト) = 0.101
# Generation: 1390. 正答率(トレーニング) = 0.06
#                 : 1390. 正答率(テスト) = 0.1028
# Generation: 1400. 正答率(トレーニング) = 0.1
#                 : 1400. 正答率(テスト) = 0.1135
# Generation: 1410. 正答率(トレーニング) = 0.09
#                 : 1410. 正答率(テスト) = 0.1135
# Generation: 1420. 正答率(トレーニング) = 0.11
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.11
#                 : 1430. 正答率(テスト) = 0.0958
# Generation: 1440. 正答率(トレーニング) = 0.12
#                 : 1440. 正答率(テスト) = 0.1135
# Generation: 1450. 正答率(トレーニング) = 0.09
#                 : 1450. 正答率(テスト) = 0.0958
# Generation: 1460. 正答率(トレーニング) = 0.13
#                 : 1460. 正答率(テスト) = 0.1028
# Generation: 1470. 正答率(トレーニング) = 0.05
#                 : 1470. 正答率(テスト) = 0.1135
# Generation: 1480. 正答率(トレーニング) = 0.09
#                 : 1480. 正答率(テスト) = 0.101
# Generation: 1490. 正答率(トレーニング) = 0.13
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.1
#                 : 1500. 正答率(テスト) = 0.0958
# Generation: 1510. 正答率(トレーニング) = 0.11
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.04
#                 : 1520. 正答率(テスト) = 0.0958
# Generation: 1530. 正答率(トレーニング) = 0.16
#                 : 1530. 正答率(テスト) = 0.1135
# Generation: 1540. 正答率(トレーニング) = 0.04
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.04
#                 : 1550. 正答率(テスト) = 0.1028
# Generation: 1560. 正答率(トレーニング) = 0.14
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.05
#                 : 1570. 正答率(テスト) = 0.1032
# Generation: 1580. 正答率(トレーニング) = 0.07
#                 : 1580. 正答率(テスト) = 0.1135
# Generation: 1590. 正答率(トレーニング) = 0.13
#                 : 1590. 正答率(テスト) = 0.1028
# Generation: 1600. 正答率(トレーニング) = 0.06
#                 : 1600. 正答率(テスト) = 0.1028
# Generation: 1610. 正答率(トレーニング) = 0.13
#                 : 1610. 正答率(テスト) = 0.1135
# Generation: 1620. 正答率(トレーニング) = 0.09
#                 : 1620. 正答率(テスト) = 0.1135
# Generation: 1630. 正答率(トレーニング) = 0.09
#                 : 1630. 正答率(テスト) = 0.1135
# Generation: 1640. 正答率(トレーニング) = 0.06
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.16
#                 : 1650. 正答率(テスト) = 0.1135
# Generation: 1660. 正答率(トレーニング) = 0.07
#                 : 1660. 正答率(テスト) = 0.1135
# Generation: 1670. 正答率(トレーニング) = 0.17
#                 : 1670. 正答率(テスト) = 0.1135
# Generation: 1680. 正答率(トレーニング) = 0.1
#                 : 1680. 正答率(テスト) = 0.1135
# Generation: 1690. 正答率(トレーニング) = 0.08
#                 : 1690. 正答率(テスト) = 0.101
# Generation: 1700. 正答率(トレーニング) = 0.1
#                 : 1700. 正答率(テスト) = 0.1135
# Generation: 1710. 正答率(トレーニング) = 0.12
#                 : 1710. 正答率(テスト) = 0.1135
# Generation: 1720. 正答率(トレーニング) = 0.12
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.08
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.08
#                 : 1740. 正答率(テスト) = 0.1135
# Generation: 1750. 正答率(トレーニング) = 0.1
#                 : 1750. 正答率(テスト) = 0.1135
# Generation: 1760. 正答率(トレーニング) = 0.09
#                 : 1760. 正答率(テスト) = 0.1135
# Generation: 1770. 正答率(トレーニング) = 0.08
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.06
#                 : 1780. 正答率(テスト) = 0.098
# Generation: 1790. 正答率(トレーニング) = 0.15
#                 : 1790. 正答率(テスト) = 0.1135
# Generation: 1800. 正答率(トレーニング) = 0.11
#                 : 1800. 正答率(テスト) = 0.1135
# Generation: 1810. 正答率(トレーニング) = 0.15
#                 : 1810. 正答率(テスト) = 0.1135
# Generation: 1820. 正答率(トレーニング) = 0.09
#                 : 1820. 正答率(テスト) = 0.1135
# Generation: 1830. 正答率(トレーニング) = 0.07
#                 : 1830. 正答率(テスト) = 0.0974
# Generation: 1840. 正答率(トレーニング) = 0.14
#                 : 1840. 正答率(テスト) = 0.1135
# Generation: 1850. 正答率(トレーニング) = 0.07
#                 : 1850. 正答率(テスト) = 0.1135
# Generation: 1860. 正答率(トレーニング) = 0.07
#                 : 1860. 正答率(テスト) = 0.1135
# Generation: 1870. 正答率(トレーニング) = 0.12
#                 : 1870. 正答率(テスト) = 0.1135
# Generation: 1880. 正答率(トレーニング) = 0.17
#                 : 1880. 正答率(テスト) = 0.1135
# Generation: 1890. 正答率(トレーニング) = 0.09
#                 : 1890. 正答率(テスト) = 0.1135
# Generation: 1900. 正答率(トレーニング) = 0.14
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.14
#                 : 1910. 正答率(テスト) = 0.1028
# Generation: 1920. 正答率(トレーニング) = 0.12
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.09
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.09
#                 : 1940. 正答率(テスト) = 0.101
# Generation: 1950. 正答率(トレーニング) = 0.11
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.14
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.15
#                 : 1970. 正答率(テスト) = 0.1135
# Generation: 1980. 正答率(トレーニング) = 0.08
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.14
#                 : 1990. 正答率(テスト) = 0.0982
# Generation: 2000. 正答率(トレーニング) = 0.08
#                 : 2000. 正答率(テスト) = 0.098

# %% [markdown]
# ## ReLU - gauss

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)
            
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############

    hidden_f = functions.relu

    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.12
#                 : 10. 正答率(テスト) = 0.1028
# Generation: 20. 正答率(トレーニング) = 0.08
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.07
#                 : 30. 正答率(テスト) = 0.1028
# Generation: 40. 正答率(トレーニング) = 0.14
#                 : 40. 正答率(テスト) = 0.1028
# Generation: 50. 正答率(トレーニング) = 0.09
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.06
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.07
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.05
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.08
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.05
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.08
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.14
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.11
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.12
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.08
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.1
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.13
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.14
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.12
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.12
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.16
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.11
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.12
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.15
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.14
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.16
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.1
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.15
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.12
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.11
#                 : 310. 正答率(テスト) = 0.1028
# Generation: 320. 正答率(トレーニング) = 0.14
#                 : 320. 正答率(テスト) = 0.1028
# Generation: 330. 正答率(トレーニング) = 0.1
#                 : 330. 正答率(テスト) = 0.1028
# Generation: 340. 正答率(トレーニング) = 0.09
#                 : 340. 正答率(テスト) = 0.1028
# Generation: 350. 正答率(トレーニング) = 0.09
#                 : 350. 正答率(テスト) = 0.1028
# Generation: 360. 正答率(トレーニング) = 0.15
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.11
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.14
#                 : 380. 正答率(テスト) = 0.1431
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1028
# Generation: 400. 正答率(トレーニング) = 0.15
#                 : 400. 正答率(テスト) = 0.1028
# Generation: 410. 正答率(トレーニング) = 0.12
#                 : 410. 正答率(テスト) = 0.1028
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1028
# Generation: 430. 正答率(トレーニング) = 0.09
#                 : 430. 正答率(テスト) = 0.1028
# Generation: 440. 正答率(トレーニング) = 0.07
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.11
#                 : 450. 正答率(テスト) = 0.1028
# Generation: 460. 正答率(トレーニング) = 0.18
#                 : 460. 正答率(テスト) = 0.1028
# Generation: 470. 正答率(トレーニング) = 0.11
#                 : 470. 正答率(テスト) = 0.1028
# Generation: 480. 正答率(トレーニング) = 0.11
#                 : 480. 正答率(テスト) = 0.1028
# Generation: 490. 正答率(トレーニング) = 0.14
#                 : 490. 正答率(テスト) = 0.1152
# Generation: 500. 正答率(トレーニング) = 0.17
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.11
#                 : 510. 正答率(テスト) = 0.1202
# Generation: 520. 正答率(トレーニング) = 0.07
#                 : 520. 正答率(テスト) = 0.1488
# Generation: 530. 正答率(トレーニング) = 0.29
#                 : 530. 正答率(テスト) = 0.2324
# Generation: 540. 正答率(トレーニング) = 0.25
#                 : 540. 正答率(テスト) = 0.2356
# Generation: 550. 正答率(トレーニング) = 0.31
#                 : 550. 正答率(テスト) = 0.231
# Generation: 560. 正答率(トレーニング) = 0.35
#                 : 560. 正答率(テスト) = 0.2341
# Generation: 570. 正答率(トレーニング) = 0.17
#                 : 570. 正答率(テスト) = 0.2002
# Generation: 580. 正答率(トレーニング) = 0.16
#                 : 580. 正答率(テスト) = 0.2189
# Generation: 590. 正答率(トレーニング) = 0.24
#                 : 590. 正答率(テスト) = 0.2749
# Generation: 600. 正答率(トレーニング) = 0.24
#                 : 600. 正答率(テスト) = 0.2754
# Generation: 610. 正答率(トレーニング) = 0.35
#                 : 610. 正答率(テスト) = 0.3229
# Generation: 620. 正答率(トレーニング) = 0.39
#                 : 620. 正答率(テスト) = 0.3068
# Generation: 630. 正答率(トレーニング) = 0.3
#                 : 630. 正答率(テスト) = 0.292
# Generation: 640. 正答率(トレーニング) = 0.35
#                 : 640. 正答率(テスト) = 0.3231
# Generation: 650. 正答率(トレーニング) = 0.26
#                 : 650. 正答率(テスト) = 0.335
# Generation: 660. 正答率(トレーニング) = 0.35
#                 : 660. 正答率(テスト) = 0.3613
# Generation: 670. 正答率(トレーニング) = 0.37
#                 : 670. 正答率(テスト) = 0.4139
# Generation: 680. 正答率(トレーニング) = 0.51
#                 : 680. 正答率(テスト) = 0.4978
# Generation: 690. 正答率(トレーニング) = 0.5
#                 : 690. 正答率(テスト) = 0.4745
# Generation: 700. 正答率(トレーニング) = 0.48
#                 : 700. 正答率(テスト) = 0.4902
# Generation: 710. 正答率(トレーニング) = 0.63
#                 : 710. 正答率(テスト) = 0.5056
# Generation: 720. 正答率(トレーニング) = 0.57
#                 : 720. 正答率(テスト) = 0.5542
# Generation: 730. 正答率(トレーニング) = 0.56
#                 : 730. 正答率(テスト) = 0.5505
# Generation: 740. 正答率(トレーニング) = 0.51
#                 : 740. 正答率(テスト) = 0.5375
# Generation: 750. 正答率(トレーニング) = 0.58
#                 : 750. 正答率(テスト) = 0.5923
# Generation: 760. 正答率(トレーニング) = 0.56
#                 : 760. 正答率(テスト) = 0.5574
# Generation: 770. 正答率(トレーニング) = 0.54
#                 : 770. 正答率(テスト) = 0.6279
# Generation: 780. 正答率(トレーニング) = 0.69
#                 : 780. 正答率(テスト) = 0.6306
# Generation: 790. 正答率(トレーニング) = 0.59
#                 : 790. 正答率(テスト) = 0.6524
# Generation: 800. 正答率(トレーニング) = 0.59
#                 : 800. 正答率(テスト) = 0.6791
# Generation: 810. 正答率(トレーニング) = 0.77
#                 : 810. 正答率(テスト) = 0.6992
# Generation: 820. 正答率(トレーニング) = 0.73
#                 : 820. 正答率(テスト) = 0.6854
# Generation: 830. 正答率(トレーニング) = 0.73
#                 : 830. 正答率(テスト) = 0.6912
# Generation: 840. 正答率(トレーニング) = 0.69
#                 : 840. 正答率(テスト) = 0.7402
# Generation: 850. 正答率(トレーニング) = 0.71
#                 : 850. 正答率(テスト) = 0.7489
# Generation: 860. 正答率(トレーニング) = 0.74
#                 : 860. 正答率(テスト) = 0.7783
# Generation: 870. 正答率(トレーニング) = 0.79
#                 : 870. 正答率(テスト) = 0.7754
# Generation: 880. 正答率(トレーニング) = 0.76
#                 : 880. 正答率(テスト) = 0.7701
# Generation: 890. 正答率(トレーニング) = 0.87
#                 : 890. 正答率(テスト) = 0.8029
# Generation: 900. 正答率(トレーニング) = 0.76
#                 : 900. 正答率(テスト) = 0.7519
# Generation: 910. 正答率(トレーニング) = 0.76
#                 : 910. 正答率(テスト) = 0.7798
# Generation: 920. 正答率(トレーニング) = 0.76
#                 : 920. 正答率(テスト) = 0.7367
# Generation: 930. 正答率(トレーニング) = 0.86
#                 : 930. 正答率(テスト) = 0.8074
# Generation: 940. 正答率(トレーニング) = 0.68
#                 : 940. 正答率(テスト) = 0.8095
# Generation: 950. 正答率(トレーニング) = 0.73
#                 : 950. 正答率(テスト) = 0.787
# Generation: 960. 正答率(トレーニング) = 0.76
#                 : 960. 正答率(テスト) = 0.7924
# Generation: 970. 正答率(トレーニング) = 0.78
#                 : 970. 正答率(テスト) = 0.8163
# Generation: 980. 正答率(トレーニング) = 0.75
#                 : 980. 正答率(テスト) = 0.8153
# Generation: 990. 正答率(トレーニング) = 0.88
#                 : 990. 正答率(テスト) = 0.8223
# Generation: 1000. 正答率(トレーニング) = 0.85
#                 : 1000. 正答率(テスト) = 0.8022
# Generation: 1010. 正答率(トレーニング) = 0.71
#                 : 1010. 正答率(テスト) = 0.8124
# Generation: 1020. 正答率(トレーニング) = 0.81
#                 : 1020. 正答率(テスト) = 0.8225
# Generation: 1030. 正答率(トレーニング) = 0.88
#                 : 1030. 正答率(テスト) = 0.8258
# Generation: 1040. 正答率(トレーニング) = 0.76
#                 : 1040. 正答率(テスト) = 0.7872
# Generation: 1050. 正答率(トレーニング) = 0.89
#                 : 1050. 正答率(テスト) = 0.836
# Generation: 1060. 正答率(トレーニング) = 0.81
#                 : 1060. 正答率(テスト) = 0.7952
# Generation: 1070. 正答率(トレーニング) = 0.87
#                 : 1070. 正答率(テスト) = 0.8337
# Generation: 1080. 正答率(トレーニング) = 0.88
#                 : 1080. 正答率(テスト) = 0.8332
# Generation: 1090. 正答率(トレーニング) = 0.66
#                 : 1090. 正答率(テスト) = 0.7801
# Generation: 1100. 正答率(トレーニング) = 0.72
#                 : 1100. 正答率(テスト) = 0.8317
# Generation: 1110. 正答率(トレーニング) = 0.84
#                 : 1110. 正答率(テスト) = 0.8152
# Generation: 1120. 正答率(トレーニング) = 0.87
#                 : 1120. 正答率(テスト) = 0.8484
# Generation: 1130. 正答率(トレーニング) = 0.86
#                 : 1130. 正答率(テスト) = 0.8404
# Generation: 1140. 正答率(トレーニング) = 0.84
#                 : 1140. 正答率(テスト) = 0.8407
# Generation: 1150. 正答率(トレーニング) = 0.86
#                 : 1150. 正答率(テスト) = 0.8524
# Generation: 1160. 正答率(トレーニング) = 0.83
#                 : 1160. 正答率(テスト) = 0.8416
# Generation: 1170. 正答率(トレーニング) = 0.85
#                 : 1170. 正答率(テスト) = 0.838
# Generation: 1180. 正答率(トレーニング) = 0.87
#                 : 1180. 正答率(テスト) = 0.8476
# Generation: 1190. 正答率(トレーニング) = 0.83
#                 : 1190. 正答率(テスト) = 0.8555
# Generation: 1200. 正答率(トレーニング) = 0.89
#                 : 1200. 正答率(テスト) = 0.8529
# Generation: 1210. 正答率(トレーニング) = 0.83
#                 : 1210. 正答率(テスト) = 0.8441
# Generation: 1220. 正答率(トレーニング) = 0.86
#                 : 1220. 正答率(テスト) = 0.8367
# Generation: 1230. 正答率(トレーニング) = 0.84
#                 : 1230. 正答率(テスト) = 0.8567
# Generation: 1240. 正答率(トレーニング) = 0.88
#                 : 1240. 正答率(テスト) = 0.8528
# Generation: 1250. 正答率(トレーニング) = 0.79
#                 : 1250. 正答率(テスト) = 0.8576
# Generation: 1260. 正答率(トレーニング) = 0.85
#                 : 1260. 正答率(テスト) = 0.8584
# Generation: 1270. 正答率(トレーニング) = 0.8
#                 : 1270. 正答率(テスト) = 0.8602
# Generation: 1280. 正答率(トレーニング) = 0.86
#                 : 1280. 正答率(テスト) = 0.8584
# Generation: 1290. 正答率(トレーニング) = 0.89
#                 : 1290. 正答率(テスト) = 0.8654
# Generation: 1300. 正答率(トレーニング) = 0.85
#                 : 1300. 正答率(テスト) = 0.8639
# Generation: 1310. 正答率(トレーニング) = 0.84
#                 : 1310. 正答率(テスト) = 0.8649
# Generation: 1320. 正答率(トレーニング) = 0.89
#                 : 1320. 正答率(テスト) = 0.8671
# Generation: 1330. 正答率(トレーニング) = 0.86
#                 : 1330. 正答率(テスト) = 0.8696
# Generation: 1340. 正答率(トレーニング) = 0.89
#                 : 1340. 正答率(テスト) = 0.8724
# Generation: 1350. 正答率(トレーニング) = 0.92
#                 : 1350. 正答率(テスト) = 0.8599
# Generation: 1360. 正答率(トレーニング) = 0.9
#                 : 1360. 正答率(テスト) = 0.8766
# Generation: 1370. 正答率(トレーニング) = 0.91
#                 : 1370. 正答率(テスト) = 0.8708
# Generation: 1380. 正答率(トレーニング) = 0.92
#                 : 1380. 正答率(テスト) = 0.8749
# Generation: 1390. 正答率(トレーニング) = 0.87
#                 : 1390. 正答率(テスト) = 0.8693
# Generation: 1400. 正答率(トレーニング) = 0.87
#                 : 1400. 正答率(テスト) = 0.8757
# Generation: 1410. 正答率(トレーニング) = 0.86
#                 : 1410. 正答率(テスト) = 0.8779
# Generation: 1420. 正答率(トレーニング) = 0.9
#                 : 1420. 正答率(テスト) = 0.86
# Generation: 1430. 正答率(トレーニング) = 0.82
#                 : 1430. 正答率(テスト) = 0.8622
# Generation: 1440. 正答率(トレーニング) = 0.91
#                 : 1440. 正答率(テスト) = 0.8853
# Generation: 1450. 正答率(トレーニング) = 0.9
#                 : 1450. 正答率(テスト) = 0.8536
# Generation: 1460. 正答率(トレーニング) = 0.93
#                 : 1460. 正答率(テスト) = 0.8813
# Generation: 1470. 正答率(トレーニング) = 0.89
#                 : 1470. 正答率(テスト) = 0.8799
# Generation: 1480. 正答率(トレーニング) = 0.94
#                 : 1480. 正答率(テスト) = 0.8843
# Generation: 1490. 正答率(トレーニング) = 0.86
#                 : 1490. 正答率(テスト) = 0.8826
# Generation: 1500. 正答率(トレーニング) = 0.89
#                 : 1500. 正答率(テスト) = 0.8855
# Generation: 1510. 正答率(トレーニング) = 0.87
#                 : 1510. 正答率(テスト) = 0.8826
# Generation: 1520. 正答率(トレーニング) = 0.91
#                 : 1520. 正答率(テスト) = 0.8912
# Generation: 1530. 正答率(トレーニング) = 0.87
#                 : 1530. 正答率(テスト) = 0.889
# Generation: 1540. 正答率(トレーニング) = 0.86
#                 : 1540. 正答率(テスト) = 0.89
# Generation: 1550. 正答率(トレーニング) = 0.91
#                 : 1550. 正答率(テスト) = 0.8937
# Generation: 1560. 正答率(トレーニング) = 0.94
#                 : 1560. 正答率(テスト) = 0.8955
# Generation: 1570. 正答率(トレーニング) = 0.91
#                 : 1570. 正答率(テスト) = 0.8901
# Generation: 1580. 正答率(トレーニング) = 0.96
#                 : 1580. 正答率(テスト) = 0.8835
# Generation: 1590. 正答率(トレーニング) = 0.9
#                 : 1590. 正答率(テスト) = 0.8901
# Generation: 1600. 正答率(トレーニング) = 0.92
#                 : 1600. 正答率(テスト) = 0.8961
# Generation: 1610. 正答率(トレーニング) = 0.92
#                 : 1610. 正答率(テスト) = 0.8956
# Generation: 1620. 正答率(トレーニング) = 0.86
#                 : 1620. 正答率(テスト) = 0.8913
# Generation: 1630. 正答率(トレーニング) = 0.91
#                 : 1630. 正答率(テスト) = 0.8981
# Generation: 1640. 正答率(トレーニング) = 0.83
#                 : 1640. 正答率(テスト) = 0.8622
# Generation: 1650. 正答率(トレーニング) = 0.86
#                 : 1650. 正答率(テスト) = 0.886
# Generation: 1660. 正答率(トレーニング) = 0.9
#                 : 1660. 正答率(テスト) = 0.8801
# Generation: 1670. 正答率(トレーニング) = 0.93
#                 : 1670. 正答率(テスト) = 0.9047
# Generation: 1680. 正答率(トレーニング) = 0.9
#                 : 1680. 正答率(テスト) = 0.8982
# Generation: 1690. 正答率(トレーニング) = 0.89
#                 : 1690. 正答率(テスト) = 0.9053
# Generation: 1700. 正答率(トレーニング) = 0.92
#                 : 1700. 正答率(テスト) = 0.9071
# Generation: 1710. 正答率(トレーニング) = 0.92
#                 : 1710. 正答率(テスト) = 0.906
# Generation: 1720. 正答率(トレーニング) = 0.89
#                 : 1720. 正答率(テスト) = 0.9034
# Generation: 1730. 正答率(トレーニング) = 0.87
#                 : 1730. 正答率(テスト) = 0.9092
# Generation: 1740. 正答率(トレーニング) = 0.91
#                 : 1740. 正答率(テスト) = 0.9059
# Generation: 1750. 正答率(トレーニング) = 0.92
#                 : 1750. 正答率(テスト) = 0.9076
# Generation: 1760. 正答率(トレーニング) = 0.87
#                 : 1760. 正答率(テスト) = 0.904
# Generation: 1770. 正答率(トレーニング) = 0.94
#                 : 1770. 正答率(テスト) = 0.9071
# Generation: 1780. 正答率(トレーニング) = 0.92
#                 : 1780. 正答率(テスト) = 0.9064
# Generation: 1790. 正答率(トレーニング) = 0.93
#                 : 1790. 正答率(テスト) = 0.9126
# Generation: 1800. 正答率(トレーニング) = 0.89
#                 : 1800. 正答率(テスト) = 0.9011
# Generation: 1810. 正答率(トレーニング) = 0.86
#                 : 1810. 正答率(テスト) = 0.9097
# Generation: 1820. 正答率(トレーニング) = 0.95
#                 : 1820. 正答率(テスト) = 0.9081
# Generation: 1830. 正答率(トレーニング) = 0.94
#                 : 1830. 正答率(テスト) = 0.9098
# Generation: 1840. 正答率(トレーニング) = 0.94
#                 : 1840. 正答率(テスト) = 0.9154
# Generation: 1850. 正答率(トレーニング) = 0.92
#                 : 1850. 正答率(テスト) = 0.9116
# Generation: 1860. 正答率(トレーニング) = 0.91
#                 : 1860. 正答率(テスト) = 0.9017
# Generation: 1870. 正答率(トレーニング) = 0.88
#                 : 1870. 正答率(テスト) = 0.9088
# Generation: 1880. 正答率(トレーニング) = 0.93
#                 : 1880. 正答率(テスト) = 0.9137
# Generation: 1890. 正答率(トレーニング) = 0.9
#                 : 1890. 正答率(テスト) = 0.9117
# Generation: 1900. 正答率(トレーニング) = 0.89
#                 : 1900. 正答率(テスト) = 0.9083
# Generation: 1910. 正答率(トレーニング) = 0.91
#                 : 1910. 正答率(テスト) = 0.894
# Generation: 1920. 正答率(トレーニング) = 0.86
#                 : 1920. 正答率(テスト) = 0.9146
# Generation: 1930. 正答率(トレーニング) = 0.92
#                 : 1930. 正答率(テスト) = 0.9142
# Generation: 1940. 正答率(トレーニング) = 0.93
#                 : 1940. 正答率(テスト) = 0.9159
# Generation: 1950. 正答率(トレーニング) = 0.85
#                 : 1950. 正答率(テスト) = 0.9131
# Generation: 1960. 正答率(トレーニング) = 0.95
#                 : 1960. 正答率(テスト) = 0.9198
# Generation: 1970. 正答率(トレーニング) = 0.93
#                 : 1970. 正答率(テスト) = 0.9177
# Generation: 1980. 正答率(トレーニング) = 0.91
#                 : 1980. 正答率(テスト) = 0.9187
# Generation: 1990. 正答率(トレーニング) = 0.94
#                 : 1990. 正答率(テスト) = 0.9148
# Generation: 2000. 正答率(トレーニング) = 0.82
#                 : 2000. 正答率(テスト) = 0.9156

# %% [markdown]
# ## sigmoid - Xavier

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20
#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    
    ###########  変更箇所  ##############
    
    # Xavierの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / (np.sqrt(input_layer_size))
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / (np.sqrt(hidden_layer_1_size))
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / (np.sqrt(hidden_layer_2_size))
    
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11
#                 : 10. 正答率(テスト) = 0.1483
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.147
# Generation: 30. 正答率(トレーニング) = 0.08
#                 : 30. 正答率(テスト) = 0.1365
# Generation: 40. 正答率(トレーニング) = 0.17
#                 : 40. 正答率(テスト) = 0.1958
# Generation: 50. 正答率(トレーニング) = 0.22
#                 : 50. 正答率(テスト) = 0.2402
# Generation: 60. 正答率(トレーニング) = 0.14
#                 : 60. 正答率(テスト) = 0.1866
# Generation: 70. 正答率(トレーニング) = 0.31
#                 : 70. 正答率(テスト) = 0.3014
# Generation: 80. 正答率(トレーニング) = 0.14
#                 : 80. 正答率(テスト) = 0.1588
# Generation: 90. 正答率(トレーニング) = 0.27
#                 : 90. 正答率(テスト) = 0.2869
# Generation: 100. 正答率(トレーニング) = 0.23
#                 : 100. 正答率(テスト) = 0.2505
# Generation: 110. 正答率(トレーニング) = 0.16
#                 : 110. 正答率(テスト) = 0.3233
# Generation: 120. 正答率(トレーニング) = 0.27
#                 : 120. 正答率(テスト) = 0.3608
# Generation: 130. 正答率(トレーニング) = 0.26
#                 : 130. 正答率(テスト) = 0.3017
# Generation: 140. 正答率(トレーニング) = 0.5
#                 : 140. 正答率(テスト) = 0.5223
# Generation: 150. 正答率(トレーニング) = 0.54
#                 : 150. 正答率(テスト) = 0.5162
# Generation: 160. 正答率(トレーニング) = 0.29
#                 : 160. 正答率(テスト) = 0.2766
# Generation: 170. 正答率(トレーニング) = 0.39
#                 : 170. 正答率(テスト) = 0.326
# Generation: 180. 正答率(トレーニング) = 0.39
#                 : 180. 正答率(テスト) = 0.3779
# Generation: 190. 正答率(トレーニング) = 0.53
#                 : 190. 正答率(テスト) = 0.4476
# Generation: 200. 正答率(トレーニング) = 0.4
#                 : 200. 正答率(テスト) = 0.4295
# Generation: 210. 正答率(トレーニング) = 0.54
#                 : 210. 正答率(テスト) = 0.4967
# Generation: 220. 正答率(トレーニング) = 0.41
#                 : 220. 正答率(テスト) = 0.4439
# Generation: 230. 正答率(トレーニング) = 0.22
#                 : 230. 正答率(テスト) = 0.3481
# Generation: 240. 正答率(トレーニング) = 0.46
#                 : 240. 正答率(テスト) = 0.4976
# Generation: 250. 正答率(トレーニング) = 0.47
#                 : 250. 正答率(テスト) = 0.5335
# Generation: 260. 正答率(トレーニング) = 0.57
#                 : 260. 正答率(テスト) = 0.5564
# Generation: 270. 正答率(トレーニング) = 0.53
#                 : 270. 正答率(テスト) = 0.5091
# Generation: 280. 正答率(トレーニング) = 0.64
#                 : 280. 正答率(テスト) = 0.5807
# Generation: 290. 正答率(トレーニング) = 0.48
#                 : 290. 正答率(テスト) = 0.4857
# Generation: 300. 正答率(トレーニング) = 0.48
#                 : 300. 正答率(テスト) = 0.5094
# Generation: 310. 正答率(トレーニング) = 0.54
#                 : 310. 正答率(テスト) = 0.5347
# Generation: 320. 正答率(トレーニング) = 0.55
#                 : 320. 正答率(テスト) = 0.4931
# Generation: 330. 正答率(トレーニング) = 0.55
#                 : 330. 正答率(テスト) = 0.475
# Generation: 340. 正答率(トレーニング) = 0.43
#                 : 340. 正答率(テスト) = 0.495
# Generation: 350. 正答率(トレーニング) = 0.5
#                 : 350. 正答率(テスト) = 0.5156
# Generation: 360. 正答率(トレーニング) = 0.48
#                 : 360. 正答率(テスト) = 0.4963
# Generation: 370. 正答率(トレーニング) = 0.56
#                 : 370. 正答率(テスト) = 0.5374
# Generation: 380. 正答率(トレーニング) = 0.54
#                 : 380. 正答率(テスト) = 0.5195
# Generation: 390. 正答率(トレーニング) = 0.56
#                 : 390. 正答率(テスト) = 0.5375
# Generation: 400. 正答率(トレーニング) = 0.44
#                 : 400. 正答率(テスト) = 0.5372
# Generation: 410. 正答率(トレーニング) = 0.57
#                 : 410. 正答率(テスト) = 0.5469
# Generation: 420. 正答率(トレーニング) = 0.53
#                 : 420. 正答率(テスト) = 0.5423
# Generation: 430. 正答率(トレーニング) = 0.51
#                 : 430. 正答率(テスト) = 0.541
# Generation: 440. 正答率(トレーニング) = 0.54
#                 : 440. 正答率(テスト) = 0.5442
# Generation: 450. 正答率(トレーニング) = 0.49
#                 : 450. 正答率(テスト) = 0.5463
# Generation: 460. 正答率(トレーニング) = 0.58
#                 : 460. 正答率(テスト) = 0.5527
# Generation: 470. 正答率(トレーニング) = 0.57
#                 : 470. 正答率(テスト) = 0.5594
# Generation: 480. 正答率(トレーニング) = 0.57
#                 : 480. 正答率(テスト) = 0.5758
# Generation: 490. 正答率(トレーニング) = 0.54
#                 : 490. 正答率(テスト) = 0.5721
# Generation: 500. 正答率(トレーニング) = 0.59
#                 : 500. 正答率(テスト) = 0.57
# Generation: 510. 正答率(トレーニング) = 0.62
#                 : 510. 正答率(テスト) = 0.5701
# Generation: 520. 正答率(トレーニング) = 0.42
#                 : 520. 正答率(テスト) = 0.5771
# Generation: 530. 正答率(トレーニング) = 0.52
#                 : 530. 正答率(テスト) = 0.5938
# Generation: 540. 正答率(トレーニング) = 0.58
#                 : 540. 正答率(テスト) = 0.5884
# Generation: 550. 正答率(トレーニング) = 0.56
#                 : 550. 正答率(テスト) = 0.5915
# Generation: 560. 正答率(トレーニング) = 0.64
#                 : 560. 正答率(テスト) = 0.5933
# Generation: 570. 正答率(トレーニング) = 0.56
#                 : 570. 正答率(テスト) = 0.5951
# Generation: 580. 正答率(トレーニング) = 0.64
#                 : 580. 正答率(テスト) = 0.5984
# Generation: 590. 正答率(トレーニング) = 0.51
#                 : 590. 正答率(テスト) = 0.5939
# Generation: 600. 正答率(トレーニング) = 0.59
#                 : 600. 正答率(テスト) = 0.5964
# Generation: 610. 正答率(トレーニング) = 0.71
#                 : 610. 正答率(テスト) = 0.5983
# Generation: 620. 正答率(トレーニング) = 0.63
#                 : 620. 正答率(テスト) = 0.6025
# Generation: 630. 正答率(トレーニング) = 0.64
#                 : 630. 正答率(テスト) = 0.6089
# Generation: 640. 正答率(トレーニング) = 0.54
#                 : 640. 正答率(テスト) = 0.6112
# Generation: 650. 正答率(トレーニング) = 0.62
#                 : 650. 正答率(テスト) = 0.6178
# Generation: 660. 正答率(トレーニング) = 0.71
#                 : 660. 正答率(テスト) = 0.6208
# Generation: 670. 正答率(トレーニング) = 0.6
#                 : 670. 正答率(テスト) = 0.6287
# Generation: 680. 正答率(トレーニング) = 0.66
#                 : 680. 正答率(テスト) = 0.6217
# Generation: 690. 正答率(トレーニング) = 0.61
#                 : 690. 正答率(テスト) = 0.6204
# Generation: 700. 正答率(トレーニング) = 0.5
#                 : 700. 正答率(テスト) = 0.6219
# Generation: 710. 正答率(トレーニング) = 0.62
#                 : 710. 正答率(テスト) = 0.6254
# Generation: 720. 正答率(トレーニング) = 0.57
#                 : 720. 正答率(テスト) = 0.6324
# Generation: 730. 正答率(トレーニング) = 0.5
#                 : 730. 正答率(テスト) = 0.6316
# Generation: 740. 正答率(トレーニング) = 0.61
#                 : 740. 正答率(テスト) = 0.6364
# Generation: 750. 正答率(トレーニング) = 0.66
#                 : 750. 正答率(テスト) = 0.64
# Generation: 760. 正答率(トレーニング) = 0.62
#                 : 760. 正答率(テスト) = 0.6334
# Generation: 770. 正答率(トレーニング) = 0.69
#                 : 770. 正答率(テスト) = 0.6399
# Generation: 780. 正答率(トレーニング) = 0.66
#                 : 780. 正答率(テスト) = 0.6367
# Generation: 790. 正答率(トレーニング) = 0.62
#                 : 790. 正答率(テスト) = 0.6419
# Generation: 800. 正答率(トレーニング) = 0.7
#                 : 800. 正答率(テスト) = 0.644
# Generation: 810. 正答率(トレーニング) = 0.73
#                 : 810. 正答率(テスト) = 0.6488
# Generation: 820. 正答率(トレーニング) = 0.61
#                 : 820. 正答率(テスト) = 0.6513
# Generation: 830. 正答率(トレーニング) = 0.62
#                 : 830. 正答率(テスト) = 0.6556
# Generation: 840. 正答率(トレーニング) = 0.65
#                 : 840. 正答率(テスト) = 0.6655
# Generation: 850. 正答率(トレーニング) = 0.73
#                 : 850. 正答率(テスト) = 0.6669
# Generation: 860. 正答率(トレーニング) = 0.62
#                 : 860. 正答率(テスト) = 0.6642
# Generation: 870. 正答率(トレーニング) = 0.68
#                 : 870. 正答率(テスト) = 0.6598
# Generation: 880. 正答率(トレーニング) = 0.65
#                 : 880. 正答率(テスト) = 0.6591
# Generation: 890. 正答率(トレーニング) = 0.61
#                 : 890. 正答率(テスト) = 0.6633
# Generation: 900. 正答率(トレーニング) = 0.65
#                 : 900. 正答率(テスト) = 0.6759
# Generation: 910. 正答率(トレーニング) = 0.7
#                 : 910. 正答率(テスト) = 0.6811
# Generation: 920. 正答率(トレーニング) = 0.63
#                 : 920. 正答率(テスト) = 0.6873
# Generation: 930. 正答率(トレーニング) = 0.66
#                 : 930. 正答率(テスト) = 0.6924
# Generation: 940. 正答率(トレーニング) = 0.67
#                 : 940. 正答率(テスト) = 0.6904
# Generation: 950. 正答率(トレーニング) = 0.65
#                 : 950. 正答率(テスト) = 0.6827
# Generation: 960. 正答率(トレーニング) = 0.75
#                 : 960. 正答率(テスト) = 0.679
# Generation: 970. 正答率(トレーニング) = 0.71
#                 : 970. 正答率(テスト) = 0.6826
# Generation: 980. 正答率(トレーニング) = 0.68
#                 : 980. 正答率(テスト) = 0.6794
# Generation: 990. 正答率(トレーニング) = 0.72
#                 : 990. 正答率(テスト) = 0.6853
# Generation: 1000. 正答率(トレーニング) = 0.73
#                 : 1000. 正答率(テスト) = 0.6874
# Generation: 1010. 正答率(トレーニング) = 0.73
#                 : 1010. 正答率(テスト) = 0.6935
# Generation: 1020. 正答率(トレーニング) = 0.65
#                 : 1020. 正答率(テスト) = 0.7059
# Generation: 1030. 正答率(トレーニング) = 0.73
#                 : 1030. 正答率(テスト) = 0.7117
# Generation: 1040. 正答率(トレーニング) = 0.72
#                 : 1040. 正答率(テスト) = 0.7107
# Generation: 1050. 正答率(トレーニング) = 0.77
#                 : 1050. 正答率(テスト) = 0.6969
# Generation: 1060. 正答率(トレーニング) = 0.67
#                 : 1060. 正答率(テスト) = 0.706
# Generation: 1070. 正答率(トレーニング) = 0.67
#                 : 1070. 正答率(テスト) = 0.7059
# Generation: 1080. 正答率(トレーニング) = 0.67
#                 : 1080. 正答率(テスト) = 0.7117
# Generation: 1090. 正答率(トレーニング) = 0.76
#                 : 1090. 正答率(テスト) = 0.7192
# Generation: 1100. 正答率(トレーニング) = 0.73
#                 : 1100. 正答率(テスト) = 0.7131
# Generation: 1110. 正答率(トレーニング) = 0.73
#                 : 1110. 正答率(テスト) = 0.7186
# Generation: 1120. 正答率(トレーニング) = 0.73
#                 : 1120. 正答率(テスト) = 0.7192
# Generation: 1130. 正答率(トレーニング) = 0.62
#                 : 1130. 正答率(テスト) = 0.723
# Generation: 1140. 正答率(トレーニング) = 0.72
#                 : 1140. 正答率(テスト) = 0.7338
# Generation: 1150. 正答率(トレーニング) = 0.68
#                 : 1150. 正答率(テスト) = 0.7327
# Generation: 1160. 正答率(トレーニング) = 0.71
#                 : 1160. 正答率(テスト) = 0.7327
# Generation: 1170. 正答率(トレーニング) = 0.68
#                 : 1170. 正答率(テスト) = 0.7211
# Generation: 1180. 正答率(トレーニング) = 0.73
#                 : 1180. 正答率(テスト) = 0.7284
# Generation: 1190. 正答率(トレーニング) = 0.74
#                 : 1190. 正答率(テスト) = 0.731
# Generation: 1200. 正答率(トレーニング) = 0.77
#                 : 1200. 正答率(テスト) = 0.7374
# Generation: 1210. 正答率(トレーニング) = 0.8
#                 : 1210. 正答率(テスト) = 0.7397
# Generation: 1220. 正答率(トレーニング) = 0.77
#                 : 1220. 正答率(テスト) = 0.7451
# Generation: 1230. 正答率(トレーニング) = 0.71
#                 : 1230. 正答率(テスト) = 0.7487
# Generation: 1240. 正答率(トレーニング) = 0.72
#                 : 1240. 正答率(テスト) = 0.7427
# Generation: 1250. 正答率(トレーニング) = 0.7
#                 : 1250. 正答率(テスト) = 0.7471
# Generation: 1260. 正答率(トレーニング) = 0.72
#                 : 1260. 正答率(テスト) = 0.7487
# Generation: 1270. 正答率(トレーニング) = 0.8
#                 : 1270. 正答率(テスト) = 0.7512
# Generation: 1280. 正答率(トレーニング) = 0.67
#                 : 1280. 正答率(テスト) = 0.746
# Generation: 1290. 正答率(トレーニング) = 0.79
#                 : 1290. 正答率(テスト) = 0.7541
# Generation: 1300. 正答率(トレーニング) = 0.71
#                 : 1300. 正答率(テスト) = 0.7561
# Generation: 1310. 正答率(トレーニング) = 0.76
#                 : 1310. 正答率(テスト) = 0.7534
# Generation: 1320. 正答率(トレーニング) = 0.72
#                 : 1320. 正答率(テスト) = 0.7526
# Generation: 1330. 正答率(トレーニング) = 0.68
#                 : 1330. 正答率(テスト) = 0.7488
# Generation: 1340. 正答率(トレーニング) = 0.77
#                 : 1340. 正答率(テスト) = 0.7545
# Generation: 1350. 正答率(トレーニング) = 0.76
#                 : 1350. 正答率(テスト) = 0.7518
# Generation: 1360. 正答率(トレーニング) = 0.78
#                 : 1360. 正答率(テスト) = 0.766
# Generation: 1370. 正答率(トレーニング) = 0.66
#                 : 1370. 正答率(テスト) = 0.7668
# Generation: 1380. 正答率(トレーニング) = 0.72
#                 : 1380. 正答率(テスト) = 0.7683
# Generation: 1390. 正答率(トレーニング) = 0.79
#                 : 1390. 正答率(テスト) = 0.7668
# Generation: 1400. 正答率(トレーニング) = 0.78
#                 : 1400. 正答率(テスト) = 0.7681
# Generation: 1410. 正答率(トレーニング) = 0.74
#                 : 1410. 正答率(テスト) = 0.7605
# Generation: 1420. 正答率(トレーニング) = 0.79
#                 : 1420. 正答率(テスト) = 0.7683
# Generation: 1430. 正答率(トレーニング) = 0.72
#                 : 1430. 正答率(テスト) = 0.7719
# Generation: 1440. 正答率(トレーニング) = 0.73
#                 : 1440. 正答率(テスト) = 0.7709
# Generation: 1450. 正答率(トレーニング) = 0.69
#                 : 1450. 正答率(テスト) = 0.7698
# Generation: 1460. 正答率(トレーニング) = 0.75
#                 : 1460. 正答率(テスト) = 0.7706
# Generation: 1470. 正答率(トレーニング) = 0.74
#                 : 1470. 正答率(テスト) = 0.7728
# Generation: 1480. 正答率(トレーニング) = 0.72
#                 : 1480. 正答率(テスト) = 0.7767
# Generation: 1490. 正答率(トレーニング) = 0.86
#                 : 1490. 正答率(テスト) = 0.7779
# Generation: 1500. 正答率(トレーニング) = 0.7
#                 : 1500. 正答率(テスト) = 0.7746
# Generation: 1510. 正答率(トレーニング) = 0.74
#                 : 1510. 正答率(テスト) = 0.7739
# Generation: 1520. 正答率(トレーニング) = 0.78
#                 : 1520. 正答率(テスト) = 0.7796
# Generation: 1530. 正答率(トレーニング) = 0.74
#                 : 1530. 正答率(テスト) = 0.7811
# Generation: 1540. 正答率(トレーニング) = 0.81
#                 : 1540. 正答率(テスト) = 0.7846
# Generation: 1550. 正答率(トレーニング) = 0.75
#                 : 1550. 正答率(テスト) = 0.7854
# Generation: 1560. 正答率(トレーニング) = 0.76
#                 : 1560. 正答率(テスト) = 0.7868
# Generation: 1570. 正答率(トレーニング) = 0.75
#                 : 1570. 正答率(テスト) = 0.7898
# Generation: 1580. 正答率(トレーニング) = 0.79
#                 : 1580. 正答率(テスト) = 0.7903
# Generation: 1590. 正答率(トレーニング) = 0.82
#                 : 1590. 正答率(テスト) = 0.7912
# Generation: 1600. 正答率(トレーニング) = 0.76
#                 : 1600. 正答率(テスト) = 0.7934
# Generation: 1610. 正答率(トレーニング) = 0.77
#                 : 1610. 正答率(テスト) = 0.7932
# Generation: 1620. 正答率(トレーニング) = 0.78
#                 : 1620. 正答率(テスト) = 0.7923
# Generation: 1630. 正答率(トレーニング) = 0.79
#                 : 1630. 正答率(テスト) = 0.7929
# Generation: 1640. 正答率(トレーニング) = 0.81
#                 : 1640. 正答率(テスト) = 0.7928
# Generation: 1650. 正答率(トレーニング) = 0.79
#                 : 1650. 正答率(テスト) = 0.7934
# Generation: 1660. 正答率(トレーニング) = 0.72
#                 : 1660. 正答率(テスト) = 0.794
# Generation: 1670. 正答率(トレーニング) = 0.75
#                 : 1670. 正答率(テスト) = 0.7933
# Generation: 1680. 正答率(トレーニング) = 0.73
#                 : 1680. 正答率(テスト) = 0.7932
# Generation: 1690. 正答率(トレーニング) = 0.78
#                 : 1690. 正答率(テスト) = 0.7941
# Generation: 1700. 正答率(トレーニング) = 0.71
#                 : 1700. 正答率(テスト) = 0.7952
# Generation: 1710. 正答率(トレーニング) = 0.78
#                 : 1710. 正答率(テスト) = 0.7959
# Generation: 1720. 正答率(トレーニング) = 0.82
#                 : 1720. 正答率(テスト) = 0.797
# Generation: 1730. 正答率(トレーニング) = 0.76
#                 : 1730. 正答率(テスト) = 0.7975
# Generation: 1740. 正答率(トレーニング) = 0.76
#                 : 1740. 正答率(テスト) = 0.8007
# Generation: 1750. 正答率(トレーニング) = 0.83
#                 : 1750. 正答率(テスト) = 0.7998
# Generation: 1760. 正答率(トレーニング) = 0.81
#                 : 1760. 正答率(テスト) = 0.8003
# Generation: 1770. 正答率(トレーニング) = 0.75
#                 : 1770. 正答率(テスト) = 0.7963
# Generation: 1780. 正答率(トレーニング) = 0.78
#                 : 1780. 正答率(テスト) = 0.7998
# Generation: 1790. 正答率(トレーニング) = 0.78
#                 : 1790. 正答率(テスト) = 0.8016
# Generation: 1800. 正答率(トレーニング) = 0.81
#                 : 1800. 正答率(テスト) = 0.8019
# Generation: 1810. 正答率(トレーニング) = 0.77
#                 : 1810. 正答率(テスト) = 0.8016
# Generation: 1820. 正答率(トレーニング) = 0.73
#                 : 1820. 正答率(テスト) = 0.8043
# Generation: 1830. 正答率(トレーニング) = 0.78
#                 : 1830. 正答率(テスト) = 0.8032
# Generation: 1840. 正答率(トレーニング) = 0.76
#                 : 1840. 正答率(テスト) = 0.8019
# Generation: 1850. 正答率(トレーニング) = 0.85
#                 : 1850. 正答率(テスト) = 0.8079
# Generation: 1860. 正答率(トレーニング) = 0.82
#                 : 1860. 正答率(テスト) = 0.8049
# Generation: 1870. 正答率(トレーニング) = 0.82
#                 : 1870. 正答率(テスト) = 0.8059
# Generation: 1880. 正答率(トレーニング) = 0.79
#                 : 1880. 正答率(テスト) = 0.8037
# Generation: 1890. 正答率(トレーニング) = 0.83
#                 : 1890. 正答率(テスト) = 0.8085
# Generation: 1900. 正答率(トレーニング) = 0.85
#                 : 1900. 正答率(テスト) = 0.8064
# Generation: 1910. 正答率(トレーニング) = 0.86
#                 : 1910. 正答率(テスト) = 0.8055
# Generation: 1920. 正答率(トレーニング) = 0.89
#                 : 1920. 正答率(テスト) = 0.8083
# Generation: 1930. 正答率(トレーニング) = 0.85
#                 : 1930. 正答率(テスト) = 0.8105
# Generation: 1940. 正答率(トレーニング) = 0.86
#                 : 1940. 正答率(テスト) = 0.8101
# Generation: 1950. 正答率(トレーニング) = 0.9
#                 : 1950. 正答率(テスト) = 0.8105
# Generation: 1960. 正答率(トレーニング) = 0.83
#                 : 1960. 正答率(テスト) = 0.8116
# Generation: 1970. 正答率(トレーニング) = 0.81
#                 : 1970. 正答率(テスト) = 0.8115
# Generation: 1980. 正答率(トレーニング) = 0.8
#                 : 1980. 正答率(テスト) = 0.813
# Generation: 1990. 正答率(トレーニング) = 0.83
#                 : 1990. 正答率(テスト) = 0.8115
# Generation: 2000. 正答率(トレーニング) = 0.87
#                 : 2000. 正答率(テスト) = 0.8111

# %% [markdown]
# ## ReLU - He

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    ###########  変更箇所  ##############

    # Heの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / np.sqrt(hidden_layer_1_size) * np.sqrt(2)
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / np.sqrt(hidden_layer_2_size) * np.sqrt(2)
        
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_f = functions.relu
    
    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.62
#                 : 10. 正答率(テスト) = 0.5772
# Generation: 20. 正答率(トレーニング) = 0.73
#                 : 20. 正答率(テスト) = 0.6737
# Generation: 30. 正答率(トレーニング) = 0.75
#                 : 30. 正答率(テスト) = 0.7571
# Generation: 40. 正答率(トレーニング) = 0.7
#                 : 40. 正答率(テスト) = 0.7779
# Generation: 50. 正答率(トレーニング) = 0.81
#                 : 50. 正答率(テスト) = 0.794
# Generation: 60. 正答率(トレーニング) = 0.86
#                 : 60. 正答率(テスト) = 0.8273
# Generation: 70. 正答率(トレーニング) = 0.83
#                 : 70. 正答率(テスト) = 0.8449
# Generation: 80. 正答率(トレーニング) = 0.83
#                 : 80. 正答率(テスト) = 0.8331
# Generation: 90. 正答率(トレーニング) = 0.82
#                 : 90. 正答率(テスト) = 0.8424
# Generation: 100. 正答率(トレーニング) = 0.81
#                 : 100. 正答率(テスト) = 0.8465
# Generation: 110. 正答率(トレーニング) = 0.84
#                 : 110. 正答率(テスト) = 0.8605
# Generation: 120. 正答率(トレーニング) = 0.84
#                 : 120. 正答率(テスト) = 0.8794
# Generation: 130. 正答率(トレーニング) = 0.92
#                 : 130. 正答率(テスト) = 0.8783
# Generation: 140. 正答率(トレーニング) = 0.88
#                 : 140. 正答率(テスト) = 0.884
# Generation: 150. 正答率(トレーニング) = 0.89
#                 : 150. 正答率(テスト) = 0.8775
# Generation: 160. 正答率(トレーニング) = 0.9
#                 : 160. 正答率(テスト) = 0.8715
# Generation: 170. 正答率(トレーニング) = 0.95
#                 : 170. 正答率(テスト) = 0.8877
# Generation: 180. 正答率(トレーニング) = 0.9
#                 : 180. 正答率(テスト) = 0.8994
# Generation: 190. 正答率(トレーニング) = 0.86
#                 : 190. 正答率(テスト) = 0.902
# Generation: 200. 正答率(トレーニング) = 0.9
#                 : 200. 正答率(テスト) = 0.9019
# Generation: 210. 正答率(トレーニング) = 0.9
#                 : 210. 正答率(テスト) = 0.8933
# Generation: 220. 正答率(トレーニング) = 0.92
#                 : 220. 正答率(テスト) = 0.8946
# Generation: 230. 正答率(トレーニング) = 0.9
#                 : 230. 正答率(テスト) = 0.9056
# Generation: 240. 正答率(トレーニング) = 0.9
#                 : 240. 正答率(テスト) = 0.8999
# Generation: 250. 正答率(トレーニング) = 0.95
#                 : 250. 正答率(テスト) = 0.8903
# Generation: 260. 正答率(トレーニング) = 0.88
#                 : 260. 正答率(テスト) = 0.9025
# Generation: 270. 正答率(トレーニング) = 0.85
#                 : 270. 正答率(テスト) = 0.9037
# Generation: 280. 正答率(トレーニング) = 0.84
#                 : 280. 正答率(テスト) = 0.91
# Generation: 290. 正答率(トレーニング) = 0.91
#                 : 290. 正答率(テスト) = 0.8949
# Generation: 300. 正答率(トレーニング) = 0.92
#                 : 300. 正答率(テスト) = 0.9109
# Generation: 310. 正答率(トレーニング) = 0.88
#                 : 310. 正答率(テスト) = 0.9053
# Generation: 320. 正答率(トレーニング) = 0.93
#                 : 320. 正答率(テスト) = 0.904
# Generation: 330. 正答率(トレーニング) = 0.9
#                 : 330. 正答率(テスト) = 0.9085
# Generation: 340. 正答率(トレーニング) = 0.9
#                 : 340. 正答率(テスト) = 0.9148
# Generation: 350. 正答率(トレーニング) = 0.95
#                 : 350. 正答率(テスト) = 0.9103
# Generation: 360. 正答率(トレーニング) = 0.93
#                 : 360. 正答率(テスト) = 0.9094
# Generation: 370. 正答率(トレーニング) = 0.94
#                 : 370. 正答率(テスト) = 0.9154
# Generation: 380. 正答率(トレーニング) = 0.87
#                 : 380. 正答率(テスト) = 0.9119
# Generation: 390. 正答率(トレーニング) = 0.95
#                 : 390. 正答率(テスト) = 0.9128
# Generation: 400. 正答率(トレーニング) = 0.91
#                 : 400. 正答率(テスト) = 0.9173
# Generation: 410. 正答率(トレーニング) = 0.95
#                 : 410. 正答率(テスト) = 0.9187
# Generation: 420. 正答率(トレーニング) = 0.9
#                 : 420. 正答率(テスト) = 0.9171
# Generation: 430. 正答率(トレーニング) = 0.93
#                 : 430. 正答率(テスト) = 0.908
# Generation: 440. 正答率(トレーニング) = 0.89
#                 : 440. 正答率(テスト) = 0.9211
# Generation: 450. 正答率(トレーニング) = 0.89
#                 : 450. 正答率(テスト) = 0.9202
# Generation: 460. 正答率(トレーニング) = 0.92
#                 : 460. 正答率(テスト) = 0.9151
# Generation: 470. 正答率(トレーニング) = 0.89
#                 : 470. 正答率(テスト) = 0.9179
# Generation: 480. 正答率(トレーニング) = 0.92
#                 : 480. 正答率(テスト) = 0.9173
# Generation: 490. 正答率(トレーニング) = 0.9
#                 : 490. 正答率(テスト) = 0.9189
# Generation: 500. 正答率(トレーニング) = 0.91
#                 : 500. 正答率(テスト) = 0.9247
# Generation: 510. 正答率(トレーニング) = 0.88
#                 : 510. 正答率(テスト) = 0.9237
# Generation: 520. 正答率(トレーニング) = 0.9
#                 : 520. 正答率(テスト) = 0.9195
# Generation: 530. 正答率(トレーニング) = 0.94
#                 : 530. 正答率(テスト) = 0.9271
# Generation: 540. 正答率(トレーニング) = 0.96
#                 : 540. 正答率(テスト) = 0.9237
# Generation: 550. 正答率(トレーニング) = 0.94
#                 : 550. 正答率(テスト) = 0.9316
# Generation: 560. 正答率(トレーニング) = 0.91
#                 : 560. 正答率(テスト) = 0.9242
# Generation: 570. 正答率(トレーニング) = 0.93
#                 : 570. 正答率(テスト) = 0.9276
# Generation: 580. 正答率(トレーニング) = 0.91
#                 : 580. 正答率(テスト) = 0.929
# Generation: 590. 正答率(トレーニング) = 0.95
#                 : 590. 正答率(テスト) = 0.9292
# Generation: 600. 正答率(トレーニング) = 0.94
#                 : 600. 正答率(テスト) = 0.9224
# Generation: 610. 正答率(トレーニング) = 0.91
#                 : 610. 正答率(テスト) = 0.9307
# Generation: 620. 正答率(トレーニング) = 0.97
#                 : 620. 正答率(テスト) = 0.9254
# Generation: 630. 正答率(トレーニング) = 0.94
#                 : 630. 正答率(テスト) = 0.9261
# Generation: 640. 正答率(トレーニング) = 0.96
#                 : 640. 正答率(テスト) = 0.9322
# Generation: 650. 正答率(トレーニング) = 0.96
#                 : 650. 正答率(テスト) = 0.9326
# Generation: 660. 正答率(トレーニング) = 0.9
#                 : 660. 正答率(テスト) = 0.9313
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.9268
# Generation: 680. 正答率(トレーニング) = 0.87
#                 : 680. 正答率(テスト) = 0.9327
# Generation: 690. 正答率(トレーニング) = 0.95
#                 : 690. 正答率(テスト) = 0.9271
# Generation: 700. 正答率(トレーニング) = 0.97
#                 : 700. 正答率(テスト) = 0.9322
# Generation: 710. 正答率(トレーニング) = 0.93
#                 : 710. 正答率(テスト) = 0.9363
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.9378
# Generation: 730. 正答率(トレーニング) = 0.93
#                 : 730. 正答率(テスト) = 0.9352
# Generation: 740. 正答率(トレーニング) = 0.96
#                 : 740. 正答率(テスト) = 0.9313
# Generation: 750. 正答率(トレーニング) = 0.92
#                 : 750. 正答率(テスト) = 0.9366
# Generation: 760. 正答率(トレーニング) = 0.92
#                 : 760. 正答率(テスト) = 0.9361
# Generation: 770. 正答率(トレーニング) = 0.9
#                 : 770. 正答率(テスト) = 0.9271
# Generation: 780. 正答率(トレーニング) = 0.95
#                 : 780. 正答率(テスト) = 0.9347
# Generation: 790. 正答率(トレーニング) = 0.89
#                 : 790. 正答率(テスト) = 0.9367
# Generation: 800. 正答率(トレーニング) = 0.97
#                 : 800. 正答率(テスト) = 0.935
# Generation: 810. 正答率(トレーニング) = 0.95
#                 : 810. 正答率(テスト) = 0.9351
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.9389
# Generation: 830. 正答率(トレーニング) = 0.95
#                 : 830. 正答率(テスト) = 0.9386
# Generation: 840. 正答率(トレーニング) = 0.98
#                 : 840. 正答率(テスト) = 0.9397
# Generation: 850. 正答率(トレーニング) = 0.93
#                 : 850. 正答率(テスト) = 0.9364
# Generation: 860. 正答率(トレーニング) = 0.92
#                 : 860. 正答率(テスト) = 0.9355
# Generation: 870. 正答率(トレーニング) = 0.94
#                 : 870. 正答率(テスト) = 0.9357
# Generation: 880. 正答率(トレーニング) = 0.97
#                 : 880. 正答率(テスト) = 0.941
# Generation: 890. 正答率(トレーニング) = 0.95
#                 : 890. 正答率(テスト) = 0.9356
# Generation: 900. 正答率(トレーニング) = 0.93
#                 : 900. 正答率(テスト) = 0.9362
# Generation: 910. 正答率(トレーニング) = 0.96
#                 : 910. 正答率(テスト) = 0.9416
# Generation: 920. 正答率(トレーニング) = 0.9
#                 : 920. 正答率(テスト) = 0.9384
# Generation: 930. 正答率(トレーニング) = 0.91
#                 : 930. 正答率(テスト) = 0.9198
# Generation: 940. 正答率(トレーニング) = 0.92
#                 : 940. 正答率(テスト) = 0.9389
# Generation: 950. 正答率(トレーニング) = 0.93
#                 : 950. 正答率(テスト) = 0.9418
# Generation: 960. 正答率(トレーニング) = 0.95
#                 : 960. 正答率(テスト) = 0.9428
# Generation: 970. 正答率(トレーニング) = 0.92
#                 : 970. 正答率(テスト) = 0.9431
# Generation: 980. 正答率(トレーニング) = 0.9
#                 : 980. 正答率(テスト) = 0.9436
# Generation: 990. 正答率(トレーニング) = 0.95
#                 : 990. 正答率(テスト) = 0.9437
# Generation: 1000. 正答率(トレーニング) = 0.95
#                 : 1000. 正答率(テスト) = 0.9401
# Generation: 1010. 正答率(トレーニング) = 0.93
#                 : 1010. 正答率(テスト) = 0.941
# Generation: 1020. 正答率(トレーニング) = 0.95
#                 : 1020. 正答率(テスト) = 0.937
# Generation: 1030. 正答率(トレーニング) = 0.95
#                 : 1030. 正答率(テスト) = 0.9389
# Generation: 1040. 正答率(トレーニング) = 0.94
#                 : 1040. 正答率(テスト) = 0.9384
# Generation: 1050. 正答率(トレーニング) = 0.97
#                 : 1050. 正答率(テスト) = 0.9418
# Generation: 1060. 正答率(トレーニング) = 0.92
#                 : 1060. 正答率(テスト) = 0.9273
# Generation: 1070. 正答率(トレーニング) = 0.94
#                 : 1070. 正答率(テスト) = 0.9446
# Generation: 1080. 正答率(トレーニング) = 0.96
#                 : 1080. 正答率(テスト) = 0.9445
# Generation: 1090. 正答率(トレーニング) = 0.9
#                 : 1090. 正答率(テスト) = 0.9386
# Generation: 1100. 正答率(トレーニング) = 0.92
#                 : 1100. 正答率(テスト) = 0.9438
# Generation: 1110. 正答率(トレーニング) = 0.94
#                 : 1110. 正答率(テスト) = 0.9469
# Generation: 1120. 正答率(トレーニング) = 0.93
#                 : 1120. 正答率(テスト) = 0.9428
# Generation: 1130. 正答率(トレーニング) = 0.94
#                 : 1130. 正答率(テスト) = 0.9385
# Generation: 1140. 正答率(トレーニング) = 0.93
#                 : 1140. 正答率(テスト) = 0.9465
# Generation: 1150. 正答率(トレーニング) = 0.93
#                 : 1150. 正答率(テスト) = 0.948
# Generation: 1160. 正答率(トレーニング) = 0.94
#                 : 1160. 正答率(テスト) = 0.9436
# Generation: 1170. 正答率(トレーニング) = 0.93
#                 : 1170. 正答率(テスト) = 0.9441
# Generation: 1180. 正答率(トレーニング) = 0.92
#                 : 1180. 正答率(テスト) = 0.9388
# Generation: 1190. 正答率(トレーニング) = 0.94
#                 : 1190. 正答率(テスト) = 0.9474
# Generation: 1200. 正答率(トレーニング) = 0.92
#                 : 1200. 正答率(テスト) = 0.9274
# Generation: 1210. 正答率(トレーニング) = 0.95
#                 : 1210. 正答率(テスト) = 0.9477
# Generation: 1220. 正答率(トレーニング) = 0.96
#                 : 1220. 正答率(テスト) = 0.9481
# Generation: 1230. 正答率(トレーニング) = 0.94
#                 : 1230. 正答率(テスト) = 0.9408
# Generation: 1240. 正答率(トレーニング) = 0.99
#                 : 1240. 正答率(テスト) = 0.9496
# Generation: 1250. 正答率(トレーニング) = 0.99
#                 : 1250. 正答率(テスト) = 0.9466
# Generation: 1260. 正答率(トレーニング) = 0.91
#                 : 1260. 正答率(テスト) = 0.948
# Generation: 1270. 正答率(トレーニング) = 1.0
#                 : 1270. 正答率(テスト) = 0.9471
# Generation: 1280. 正答率(トレーニング) = 0.98
#                 : 1280. 正答率(テスト) = 0.942
# Generation: 1290. 正答率(トレーニング) = 0.95
#                 : 1290. 正答率(テスト) = 0.9468
# Generation: 1300. 正答率(トレーニング) = 0.97
#                 : 1300. 正答率(テスト) = 0.9419
# Generation: 1310. 正答率(トレーニング) = 0.95
#                 : 1310. 正答率(テスト) = 0.9439
# Generation: 1320. 正答率(トレーニング) = 0.94
#                 : 1320. 正答率(テスト) = 0.9449
# Generation: 1330. 正答率(トレーニング) = 0.96
#                 : 1330. 正答率(テスト) = 0.9487
# Generation: 1340. 正答率(トレーニング) = 0.97
#                 : 1340. 正答率(テスト) = 0.9472
# Generation: 1350. 正答率(トレーニング) = 0.98
#                 : 1350. 正答率(テスト) = 0.9415
# Generation: 1360. 正答率(トレーニング) = 0.95
#                 : 1360. 正答率(テスト) = 0.9479
# Generation: 1370. 正答率(トレーニング) = 0.96
#                 : 1370. 正答率(テスト) = 0.9457
# Generation: 1380. 正答率(トレーニング) = 0.96
#                 : 1380. 正答率(テスト) = 0.9523
# Generation: 1390. 正答率(トレーニング) = 0.94
#                 : 1390. 正答率(テスト) = 0.9444
# Generation: 1400. 正答率(トレーニング) = 0.93
#                 : 1400. 正答率(テスト) = 0.9495
# Generation: 1410. 正答率(トレーニング) = 0.95
#                 : 1410. 正答率(テスト) = 0.947
# Generation: 1420. 正答率(トレーニング) = 0.95
#                 : 1420. 正答率(テスト) = 0.9368
# Generation: 1430. 正答率(トレーニング) = 0.94
#                 : 1430. 正答率(テスト) = 0.9496
# Generation: 1440. 正答率(トレーニング) = 0.95
#                 : 1440. 正答率(テスト) = 0.9479
# Generation: 1450. 正答率(トレーニング) = 0.93
#                 : 1450. 正答率(テスト) = 0.9481
# Generation: 1460. 正答率(トレーニング) = 0.94
#                 : 1460. 正答率(テスト) = 0.9511
# Generation: 1470. 正答率(トレーニング) = 0.99
#                 : 1470. 正答率(テスト) = 0.9492
# Generation: 1480. 正答率(トレーニング) = 0.97
#                 : 1480. 正答率(テスト) = 0.9483
# Generation: 1490. 正答率(トレーニング) = 0.93
#                 : 1490. 正答率(テスト) = 0.9529
# Generation: 1500. 正答率(トレーニング) = 0.95
#                 : 1500. 正答率(テスト) = 0.9509
# Generation: 1510. 正答率(トレーニング) = 0.98
#                 : 1510. 正答率(テスト) = 0.9505
# Generation: 1520. 正答率(トレーニング) = 0.96
#                 : 1520. 正答率(テスト) = 0.9447
# Generation: 1530. 正答率(トレーニング) = 0.97
#                 : 1530. 正答率(テスト) = 0.9511
# Generation: 1540. 正答率(トレーニング) = 0.96
#                 : 1540. 正答率(テスト) = 0.9518
# Generation: 1550. 正答率(トレーニング) = 0.94
#                 : 1550. 正答率(テスト) = 0.9449
# Generation: 1560. 正答率(トレーニング) = 0.98
#                 : 1560. 正答率(テスト) = 0.9483
# Generation: 1570. 正答率(トレーニング) = 0.97
#                 : 1570. 正答率(テスト) = 0.9462
# Generation: 1580. 正答率(トレーニング) = 0.94
#                 : 1580. 正答率(テスト) = 0.9463
# Generation: 1590. 正答率(トレーニング) = 0.95
#                 : 1590. 正答率(テスト) = 0.9507
# Generation: 1600. 正答率(トレーニング) = 0.94
#                 : 1600. 正答率(テスト) = 0.9484
# Generation: 1610. 正答率(トレーニング) = 0.98
#                 : 1610. 正答率(テスト) = 0.9477
# Generation: 1620. 正答率(トレーニング) = 0.96
#                 : 1620. 正答率(テスト) = 0.9487
# Generation: 1630. 正答率(トレーニング) = 0.98
#                 : 1630. 正答率(テスト) = 0.9489
# Generation: 1640. 正答率(トレーニング) = 0.98
#                 : 1640. 正答率(テスト) = 0.9508
# Generation: 1650. 正答率(トレーニング) = 0.96
#                 : 1650. 正答率(テスト) = 0.9515
# Generation: 1660. 正答率(トレーニング) = 0.96
#                 : 1660. 正答率(テスト) = 0.9543
# Generation: 1670. 正答率(トレーニング) = 0.96
#                 : 1670. 正答率(テスト) = 0.9471
# Generation: 1680. 正答率(トレーニング) = 0.96
#                 : 1680. 正答率(テスト) = 0.9525
# Generation: 1690. 正答率(トレーニング) = 0.95
#                 : 1690. 正答率(テスト) = 0.9521
# Generation: 1700. 正答率(トレーニング) = 0.97
#                 : 1700. 正答率(テスト) = 0.9518
# Generation: 1710. 正答率(トレーニング) = 0.96
#                 : 1710. 正答率(テスト) = 0.951
# Generation: 1720. 正答率(トレーニング) = 0.97
#                 : 1720. 正答率(テスト) = 0.9506
# Generation: 1730. 正答率(トレーニング) = 0.94
#                 : 1730. 正答率(テスト) = 0.9494
# Generation: 1740. 正答率(トレーニング) = 0.95
#                 : 1740. 正答率(テスト) = 0.9505
# Generation: 1750. 正答率(トレーニング) = 0.94
#                 : 1750. 正答率(テスト) = 0.9498
# Generation: 1760. 正答率(トレーニング) = 0.97
#                 : 1760. 正答率(テスト) = 0.9527
# Generation: 1770. 正答率(トレーニング) = 0.92
#                 : 1770. 正答率(テスト) = 0.9517
# Generation: 1780. 正答率(トレーニング) = 0.96
#                 : 1780. 正答率(テスト) = 0.9526
# Generation: 1790. 正答率(トレーニング) = 0.96
#                 : 1790. 正答率(テスト) = 0.9516
# Generation: 1800. 正答率(トレーニング) = 0.96
#                 : 1800. 正答率(テスト) = 0.9522
# Generation: 1810. 正答率(トレーニング) = 0.97
#                 : 1810. 正答率(テスト) = 0.9534
# Generation: 1820. 正答率(トレーニング) = 0.98
#                 : 1820. 正答率(テスト) = 0.9505
# Generation: 1830. 正答率(トレーニング) = 0.95
#                 : 1830. 正答率(テスト) = 0.9515
# Generation: 1840. 正答率(トレーニング) = 0.93
#                 : 1840. 正答率(テスト) = 0.9534
# Generation: 1850. 正答率(トレーニング) = 0.96
#                 : 1850. 正答率(テスト) = 0.9519
# Generation: 1860. 正答率(トレーニング) = 0.96
#                 : 1860. 正答率(テスト) = 0.9527
# Generation: 1870. 正答率(トレーニング) = 0.94
#                 : 1870. 正答率(テスト) = 0.9541
# Generation: 1880. 正答率(トレーニング) = 0.91
#                 : 1880. 正答率(テスト) = 0.9544
# Generation: 1890. 正答率(トレーニング) = 0.93
#                 : 1890. 正答率(テスト) = 0.9469
# Generation: 1900. 正答率(トレーニング) = 0.98
#                 : 1900. 正答率(テスト) = 0.9516
# Generation: 1910. 正答率(トレーニング) = 0.98
#                 : 1910. 正答率(テスト) = 0.9548
# Generation: 1920. 正答率(トレーニング) = 0.98
#                 : 1920. 正答率(テスト) = 0.9549
# Generation: 1930. 正答率(トレーニング) = 0.96
#                 : 1930. 正答率(テスト) = 0.9558
# Generation: 1940. 正答率(トレーニング) = 0.93
#                 : 1940. 正答率(テスト) = 0.9539
# Generation: 1950. 正答率(トレーニング) = 0.96
#                 : 1950. 正答率(テスト) = 0.9505
# Generation: 1960. 正答率(トレーニング) = 0.96
#                 : 1960. 正答率(テスト) = 0.9538
# Generation: 1970. 正答率(トレーニング) = 0.95
#                 : 1970. 正答率(テスト) = 0.9514
# Generation: 1980. 正答率(トレーニング) = 0.96
#                 : 1980. 正答率(テスト) = 0.9442
# Generation: 1990. 正答率(トレーニング) = 0.97
#                 : 1990. 正答率(テスト) = 0.9518
# Generation: 2000. 正答率(トレーニング) = 0.92
#                 : 2000. 正答率(テスト) = 0.9523
